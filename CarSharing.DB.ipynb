# %%
# Question 1
# Create an SQLite database and import the data into a table named “CarSharing”. 
# Create a backup table and copy the whole table into it.

import sqlite3
import csv

# SQLite database file
database_file = "carsharing.db"

# CSV file containing the data
csv_file = "CarSharing.csv"

# Create a connection to the database
conn = sqlite3.connect(database_file)
cursor = conn.cursor()

# Create the CarSharing table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS CarSharing (
        id INTEGER,
        timestamp TEXT,
        season TEXT,
        holiday TEXT,
        workingday TEXT,
        weather TEXT,
        temp REAL,
        temp_feel REAL,
        humidity INTEGER,
        windspeed REAL,
        demand REAL
    )
""")

# Import the data from the CSV file into the CarSharing table
with open(csv_file, "r") as file:
    csv_reader = csv.reader(file)
    header = next(csv_reader)  # Get the header row
    cursor.execute("INSERT INTO CarSharing VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", header)  # Insert the header row
    cursor.executemany("INSERT INTO CarSharing VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", csv_reader)

# Create a backup table
cursor.execute("CREATE TABLE IF NOT EXISTS CarSharingBackup AS SELECT * FROM CarSharing")

# Commit the changes and close the connection
conn.commit()
conn.close()

# Print the success statement
print("Tables Created Successfully")

# SQLite database file
database_file = "carsharing.db"

# Function to print a table including the header and data up to the specified number of rows
def print_table(table_name, num_rows=5):  # Default to print 5 rows
    # Connect to the database
    conn = sqlite3.connect(database_file)
    cursor = conn.cursor()

    # Execute a SELECT query to retrieve column names and data up to the specified number of rows
    cursor.execute(f"SELECT * FROM {table_name} LIMIT {num_rows}")
    rows = cursor.fetchall()

    # Print the table name
    print(f"{table_name} Table:")

    # Print table data up to the specified number of rows
    for row in rows:
        print(",".join(str(value) for value in row))

    # Close the connection
    conn.close()

# Print the table name and specified number of rows for both tables
print_table("CarSharing", 5)  # Print 5 rows for CarSharing table
print("---")
print_table("CarSharingBackup", 5)  # Print 5 rows for CarSharingBackup table
# Out:
# Tables Created Successfully
# CarSharing Table:
# id,timestamp,season,holiday,workingday,weather,temp,temp_feel,humidity,windspeed,demand
# 1,2017-01-01 00:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,81,0.0,2.772588722239781
# 2,2017-01-01 01:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.688879454113936
# 3,2017-01-01 02:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.4657359027997265
# 4,2017-01-01 03:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,75,0.0,2.5649493574615367
# ---
# CarSharingBackup Table:
# id,timestamp,season,holiday,workingday,weather,temp,temp_feel,humidity,windspeed,demand
# 1,2017-01-01 00:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,81,0.0,2.772588722239781
# 2,2017-01-01 01:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.688879454113936
# 3,2017-01-01 02:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.4657359027997265
# 4,2017-01-01 03:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,75,0.0,2.5649493574615367

# %%
# Question 2
#Add a column to the CarSharing table named “temp_category”. This column should contain three string values. 
#If the “feels-like” temperature is less than 10 then the corresponding value in the temp_category 
#column should be “Cold”, if the feels-like temperature is between 10 and 25, the value should be “Mild”,
#and if the feels-like temperature is greater than 25,then the value should be “Hot”.

import sqlite3

# Function to print table data
def print_table_data(table_name):
    conn = sqlite3.connect('carsharing.db')
    cursor = conn.cursor()

    cursor.execute(f"SELECT * FROM {table_name}")
    rows = cursor.fetchall()

    # Print the table name
    print(f"{table_name} Table:")

    # Print the header row
    header = [description[0] for description in cursor.description]
    print(','.join(header))

    # Print the table data from the second row to the 8708th row
    for row in rows[1:8709]:
        print(','.join(str(col) for col in row))

    conn.close()

# Connect to the database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Check if the temp_category column already exists
cursor.execute("PRAGMA table_info(CarSharing)")
columns = cursor.fetchall()
temp_category_exists = False
for column in columns:
    if column[1] == 'temp_category':
        temp_category_exists = True
        break

# Add the temp_category column to the CarSharing table if it doesn't exist
if not temp_category_exists:
    cursor.execute('''ALTER TABLE CarSharing 
                      ADD COLUMN temp_category TEXT''')

# Update the temp_category column based on temp_feel values
cursor.execute('''UPDATE CarSharing 
                  SET temp_category = CASE 
                                        WHEN temp_feel = '' THEN ''
                                        WHEN temp_feel < 10.00 THEN 'Cold'
                                        WHEN temp_feel BETWEEN 10.00 AND 25.00 THEN 'Mild'
                                        ELSE 'Hot'
                                     END''')

# Print table data for CarSharing
print_table_data('CarSharing')

# Commit the changes and close the connection
conn.commit()
conn.close()
# Out:
# CarSharing Table:
# id,timestamp,season,holiday,workingday,weather,temp,temp_feel,humidity,windspeed,demand,temp_category
# 1,2017-01-01 00:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,81,0.0,2.772588722239781,None
# 2,2017-01-01 01:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.688879454113936,None
# 3,2017-01-01 02:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,80,0.0,3.4657359027997265,None
# 4,2017-01-01 03:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,75,0.0,2.5649493574615367,None
# 5,2017-01-01 04:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,75,0.0,0.0,None
# 6,2017-01-01 05:00:00,spring,No,No,Mist,9.84,12.88,75,6.0032,0.0,None
# 7,2017-01-01 06:00:00,spring,No,No,Clear or partly cloudy,,13.635,80,0.0,0.6931471805599453,None
# 8,2017-01-01 07:00:00,spring,No,No,Clear or partly cloudy,8.2,12.88,86,0.0,1.0986122886681098,None
# 9,2017-01-01 08:00:00,spring,No,No,Clear or partly cloudy,9.84,14.395,75,0.0,2.0794415416798357,None
# 10,2017-01-01 09:00:00,spring,No,No,Clear or partly cloudy,13.12,17.425,76,0.0,2.6390573296152584,None
# 11,2017-01-01 10:00:00,spring,No,No,Clear or partly cloudy,15.58,19.695,76,16.9979,3.58351893845611,None
# 12,2017-01-01 11:00:00,spring,No,No,Clear or partly cloudy,14.76,16.665,81,19.0012,4.02535169073515,None
# 13,2017-01-01 12:00:00,spring,No,No,Clear or partly cloudy,17.22,21.21,77,19.0012,4.430816798843313,None
# 14,2017-01-01 13:00:00,spring,No,No,Mist,18.86,22.725,72,19.9995,4.543294782270004,None
# 15,2017-01-01 14:00:00,spring,No,No,Mist,18.86,22.725,72,19.0012,4.663439094112067,None
# 16,2017-01-01 15:00:00,spring,No,No,Mist,18.04,21.97,77,19.9995,4.700480365792417,None
# 17,2017-01-01 16:00:00,spring,No,No,Mist,17.22,21.21,82,19.9995,4.532599493153256,None
# 18,2017-01-01 17:00:00,spring,No,No,Mist,18.04,21.97,82,19.0012,4.204692619390966,None
# 19,2017-01-01 18:00:00,spring,No,No,Light snow or rain,17.22,21.21,88,16.9979,3.5553480614894135,None
# 20,2017-01-01 19:00:00,spring,No,No,Light snow or rain,,21.21,88,16.9979,3.610917912644224,None
# 21,2017-01-01 20:00:00,spring,No,No,Mist,16.4,20.455,87,16.9979,3.58351893845611,None
# 22,2017-01-01 21:00:00,spring,No,No,Mist,16.4,20.455,87,12.998,3.5263605246161616,None
# 23,2017-01-01 22:00:00,spring,No,No,Mist,16.4,20.455,94,15.0013,3.332204510175204,None
# 24,2017-01-01 23:00:00,spring,No,No,Mist,,22.725,88,19.9995,3.6635616461296463,None
# 25,2017-01-02 00:00:00,spring,No,No,Mist,18.86,22.725,88,19.9995,2.833213344056216,None
# 26,2017-01-02 01:00:00,spring,No,No,Mist,18.04,21.97,94,16.9979,2.833213344056216,None
# 27,2017-01-02 02:00:00,spring,No,No,Mist,,21.21,100,19.0012,2.1972245773362196,None
# 28,2017-01-02 03:00:00,spring,No,No,Mist,18.86,22.725,94,12.998,1.791759469228055,None
# 29,2017-01-02 04:00:00,spring,No,No,Mist,18.86,22.725,94,12.998,1.0986122886681098,None
# 30,2017-01-02 06:00:00,spring,No,No,Light snow or rain,17.22,21.21,77,19.9995,0.6931471805599453,None
# 31,2017-01-02 07:00:00,spring,No,No,Mist,16.4,20.455,76,12.998,0.0,None
# 32,2017-01-02 08:00:00,spring,No,No,Light snow or rain,,20.455,71,15.0013,2.0794415416798357,None
# 33,2017-01-02 09:00:00,spring,No,No,Mist,15.58,19.695,76,15.0013,2.995732273553991,None
# 34,2017-01-02 10:00:00,spring,No,No,Mist,14.76,17.425,81,15.0013,3.970291913552122,None
# 35,2017-01-02 11:00:00,spring,No,No,Mist,14.76,16.665,71,16.9979,4.248495242049359,None
# 36,2017-01-02 12:00:00,spring,No,No,Mist,14.76,,66,19.9995,4.532599493153256,None
# 37,2017-01-02 13:00:00,spring,No,No,Mist,14.76,17.425,66,8.9981,4.31748811353631,None
# 38,2017-01-02 14:00:00,spring,No,No,Light snow or rain,14.76,17.425,76,12.998,4.07753744390572,None
# 39,2017-01-02 15:00:00,spring,No,No,Light snow or rain,13.94,16.665,81,11.0014,4.30406509320417,None
# 40,2017-01-02 16:00:00,spring,No,No,Light snow or rain,,16.665,71,11.0014,4.330733340286331,None
# 41,2017-01-02 17:00:00,spring,No,No,Clear or partly cloudy,13.94,16.665,57,12.998,4.174387269895637,None
# 42,2017-01-02 18:00:00,spring,No,No,Mist,14.76,16.665,46,22.0028,3.970291913552122,None
# 43,2017-01-02 19:00:00,spring,No,No,Clear or partly cloudy,13.12,14.395,42,30.0026,3.4011973816621555,None
# 44,2017-01-02 20:00:00,spring,No,No,Clear or partly cloudy,,13.635,39,23.9994,3.091042453358316,None
# 45,2017-01-02 21:00:00,spring,No,No,Clear or partly cloudy,10.66,11.365,44,22.0028,3.4339872044851463,None
# 46,2017-01-02 22:00:00,spring,No,No,Clear or partly cloudy,9.84,10.605,44,19.9995,2.1972245773362196,None
# 47,2017-01-02 23:00:00,spring,No,No,Clear or partly cloudy,,11.365,47,11.0014,2.0794415416798357,None
# 48,2017-01-03 00:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,44,23.9994,1.6094379124341005,None
# 49,2017-01-03 01:00:00,spring,No,Yes,Clear or partly cloudy,,8.335,44,27.9993,0.6931471805599453,None
# 50,2017-01-03 04:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,47,26.0027,0.0,None
# 51,2017-01-03 05:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,47,19.0012,1.0986122886681098,None
# 52,2017-01-03 06:00:00,spring,No,Yes,Clear or partly cloudy,5.74,5.305,50,26.0027,3.4011973816621555,None
# 53,2017-01-03 07:00:00,spring,No,Yes,Clear or partly cloudy,,6.82,,12.998,4.1588830833596715,None
# 54,2017-01-03 08:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,19.0012,5.0369526024136295,None
# 55,2017-01-03 09:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,43,26.0027,4.477336814478207,None
# 56,2017-01-03 10:00:00,spring,No,Yes,Clear or partly cloudy,7.38,8.335,43,16.9979,3.784189633918261,None
# 57,2017-01-03 11:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,40,22.0028,3.9318256327243257,None
# 58,2017-01-03 12:00:00,spring,No,Yes,Clear or partly cloudy,,10.605,35,19.9995,4.110873864173311,None
# 59,2017-01-03 13:00:00,spring,No,Yes,Clear or partly cloudy,9.84,10.605,35,19.0012,4.110873864173311,None
# 60,2017-01-03 14:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.12,30,19.0012,4.343805421853684,None
# 61,2017-01-03 15:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.12,30,16.9979,4.276666119016055,None
# 62,2017-01-03 16:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.12,30,16.9979,4.330733340286331,None
# 63,2017-01-03 17:00:00,spring,No,Yes,Clear or partly cloudy,9.84,11.365,30,15.0013,5.056245805348308,None
# 64,2017-01-03 18:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.88,32,7.0015,5.056245805348308,None
# 65,2017-01-03 19:00:00,spring,No,Yes,Clear or partly cloudy,8.2,12.88,47,0.0,4.700480365792417,None
# 66,2017-01-03 20:00:00,spring,No,Yes,Clear or partly cloudy,,11.365,47,7.0015,3.951243718581427,None
# 67,2017-01-03 21:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.85,64,8.9981,3.951243718581427,None
# 68,2017-01-03 22:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,69,8.9981,2.995732273553991,None
# 69,2017-01-03 23:00:00,spring,No,Yes,Clear or partly cloudy,7.38,10.605,55,7.0015,2.4849066497880004,None
# 70,2017-01-04 00:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.09,55,7.0015,1.6094379124341005,None
# 71,2017-01-04 01:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.09,59,7.0015,0.6931471805599453,None
# 72,2017-01-04 02:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,63,8.9981,0.0,None
# 73,2017-01-04 04:00:00,spring,No,Yes,Clear or partly cloudy,5.74,9.09,63,6.0032,0.6931471805599453,None
# 74,2017-01-04 05:00:00,spring,No,Yes,Clear or partly cloudy,4.92,7.575,68,7.0015,1.3862943611198906,None
# 75,2017-01-04 06:00:00,spring,No,Yes,Clear or partly cloudy,,7.575,74,7.0015,3.58351893845611,None
# 76,2017-01-04 07:00:00,spring,No,Yes,Clear or partly cloudy,4.92,7.575,74,8.9981,4.543294782270004,None
# 77,2017-01-04 08:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,69,11.0014,5.187385805840755,None
# 78,2017-01-04 09:00:00,spring,No,Yes,Clear or partly cloudy,6.56,7.575,64,,4.605170185988092,None
# 79,2017-01-04 10:00:00,spring,No,Yes,Mist,6.56,6.82,69,22.0028,3.737669618283368,None
# 80,2017-01-04 11:00:00,spring,No,Yes,Clear or partly cloudy,9.02,10.605,51,19.9995,4.04305126783455,None
# 81,2017-01-04 12:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,51,11.0014,4.356708826689592,None
# 82,2017-01-04 13:00:00,spring,No,Yes,Clear or partly cloudy,9.84,11.365,56,12.998,4.574710978503383,None
# 83,2017-01-04 14:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.88,52,15.0013,4.143134726391533,None
# 84,2017-01-04 15:00:00,spring,No,Yes,Clear or partly cloudy,,13.635,52,16.9979,4.174387269895637,None
# 85,2017-01-04 16:00:00,spring,No,Yes,Clear or partly cloudy,12.3,14.395,49,16.9979,4.418840607796598,None
# 86,2017-01-04 17:00:00,spring,No,Yes,Clear or partly cloudy,11.48,13.635,48,15.0013,5.356586274672012,None
# 87,2017-01-04 18:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.88,48,12.998,5.204006687076795,None
# 88,2017-01-04 19:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.88,48,7.0015,4.718498871295094,None
# 89,2017-01-04 20:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.88,48,7.0015,3.9889840465642745,None
# 90,2017-01-04 21:00:00,spring,No,Yes,Clear or partly cloudy,,13.635,64,0.0,3.871201010907891,None
# 91,2017-01-04 22:00:00,spring,No,Yes,Clear or partly cloudy,9.02,12.88,64,6.0032,3.5553480614894135,None
# 92,2017-01-04 23:00:00,spring,No,Yes,Clear or partly cloudy,8.2,11.365,69,6.0032,2.3978952727983707,None
# 93,2017-01-05 00:00:00,spring,No,Yes,Clear or partly cloudy,8.2,12.88,64,0.0,1.791759469228055,None
# 94,2017-01-05 01:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.85,74,6.0032,1.791759469228055,None
# 95,2017-01-05 02:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.85,74,6.0032,0.6931471805599453,None
# 96,2017-01-05 04:00:00,spring,No,Yes,Clear or partly cloudy,9.84,11.365,48,15.0013,0.6931471805599453,None
# 97,2017-01-05 05:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,47,11.0014,1.0986122886681098,None
# 98,2017-01-05 06:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.85,47,15.0013,3.49650756146648,None
# 99,2017-01-05 07:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.09,43,12.998,4.477336814478207,None
# 100,2017-01-05 08:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,40,19.9995,5.272999558563747,None
# 101,2017-01-05 09:00:00,spring,No,Yes,Clear or partly cloudy,,9.85,37,22.0028,4.74493212836325,None
# 102,2017-01-05 10:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,37,22.0028,4.04305126783455,None
# 103,2017-01-05 11:00:00,spring,No,Yes,Clear or partly cloudy,10.66,11.365,33,22.0028,3.828641396489095,None
# 104,2017-01-05 12:00:00,spring,No,Yes,Clear or partly cloudy,10.66,11.365,33,22.0028,4.3694478524670215,None
# 105,2017-01-05 13:00:00,spring,No,Yes,Clear or partly cloudy,11.48,12.88,30,19.9995,4.2626798770413155,None
# 106,2017-01-05 14:00:00,spring,No,Yes,Clear or partly cloudy,12.3,14.395,28,12.998,4.127134385045092,None
# 107,2017-01-05 15:00:00,spring,No,Yes,Clear or partly cloudy,12.3,14.395,28,12.998,4.127134385045092,None
# 108,2017-01-05 16:00:00,spring,No,Yes,Clear or partly cloudy,12.3,15.91,28,6.0032,4.48863636973214,None
# 109,2017-01-05 17:00:00,spring,No,Yes,Clear or partly cloudy,9.84,11.365,38,12.998,5.247024072160486,None
# 110,2017-01-05 18:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.12,38,8.9981,5.1298987149230735,None
# 111,2017-01-05 19:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.88,38,7.0015,4.882801922586371,None
# 112,2017-01-05 20:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,47,11.0014,4.48863636973214,None
# 113,2017-01-05 21:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.85,51,12.998,3.7612001156935624,None
# 114,2017-01-05 22:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.85,55,8.9981,3.737669618283368,None
# 115,2017-01-05 23:00:00,spring,No,Yes,Clear or partly cloudy,8.2,12.88,47,0.0,2.9444389791664403,None
# 116,2017-01-06 00:00:00,spring,No,Yes,Clear or partly cloudy,7.38,12.12,55,0.0,2.3978952727983707,None
# 117,2017-01-06 01:00:00,spring,No,Yes,Clear or partly cloudy,6.56,11.365,64,0.0,1.3862943611198906,None
# 118,2017-01-06 02:00:00,spring,No,Yes,Clear or partly cloudy,6.56,11.365,64,0.0,0.6931471805599453,None
# 119,2017-01-06 04:00:00,spring,No,Yes,Mist,6.56,9.85,64,6.0032,0.0,None
# 120,2017-01-06 05:00:00,spring,No,Yes,Mist,5.74,9.09,69,6.0032,1.3862943611198906,None
# 121,2017-01-06 06:00:00,spring,No,Yes,Mist,5.74,8.335,63,7.0015,3.58351893845611,None
# 122,2017-01-06 07:00:00,spring,No,Yes,Mist,,11.365,59,0.0,4.553876891600541,None
# 123,2017-01-06 08:00:00,spring,No,Yes,Clear or partly cloudy,6.56,11.365,59,0.0,5.389071729816501,None
# 124,2017-01-06 09:00:00,spring,No,Yes,Mist,,12.12,51,0.0,4.804021044733257,None
# 125,2017-01-06 10:00:00,spring,No,Yes,Clear or partly cloudy,8.2,12.88,47,0.0,3.80666248977032,None
# 126,2017-01-06 11:00:00,spring,No,Yes,Clear or partly cloudy,9.02,12.88,44,6.0032,4.07753744390572,None
# 127,2017-01-06 12:00:00,spring,No,Yes,Clear or partly cloudy,10.66,14.395,35,0.0,4.430816798843313,None
# 128,2017-01-06 13:00:00,spring,No,Yes,Clear or partly cloudy,10.66,13.635,35,7.0015,4.204692619390966,None
# 129,2017-01-06 14:00:00,spring,No,Yes,Clear or partly cloudy,11.48,13.635,36,11.0014,4.248495242049359,None
# 130,2017-01-06 15:00:00,spring,No,Yes,Clear or partly cloudy,11.48,13.635,36,0.0,4.127134385045092,None
# 131,2017-01-06 16:00:00,spring,No,Yes,Clear or partly cloudy,10.66,12.88,38,11.0014,4.454347296253507,None
# 132,2017-01-06 17:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,51,11.0014,5.147494476813453,None
# 133,2017-01-06 18:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,51,8.9981,5.093750200806762,None
# 134,2017-01-06 19:00:00,spring,No,Yes,Clear or partly cloudy,9.02,12.88,55,,4.718498871295094,None
# 135,2017-01-06 20:00:00,spring,No,Yes,Clear or partly cloudy,,10.605,51,11.0014,4.23410650459726,None
# 136,2017-01-06 21:00:00,spring,No,Yes,Mist,9.02,10.605,55,15.0013,3.871201010907891,None
# 137,2017-01-06 22:00:00,spring,No,Yes,Mist,9.02,10.605,51,19.0012,3.951243718581427,None
# 138,2017-01-06 23:00:00,spring,No,Yes,Mist,,9.85,59,12.998,3.1354942159291497,None
# 139,2017-01-07 00:00:00,spring,No,Yes,Mist,8.2,9.85,64,12.998,2.833213344056216,None
# 140,2017-01-07 01:00:00,spring,No,Yes,Mist,8.2,9.85,69,15.0013,1.9459101490553132,None
# 141,2017-01-07 02:00:00,spring,No,Yes,Mist,8.2,9.85,69,15.0013,0.0,None
# 142,2017-01-07 04:00:00,spring,No,Yes,Mist,8.2,10.605,69,8.9981,0.0,None
# 143,2017-01-07 05:00:00,spring,No,Yes,Light snow or rain,,13.635,55,0.0,1.6094379124341005,None
# 144,2017-01-07 06:00:00,spring,No,Yes,Mist,8.2,12.88,69,0.0,3.5263605246161616,None
# 145,2017-01-07 07:00:00,spring,No,Yes,Clear or partly cloudy,8.2,10.605,69,8.9981,4.430816798843313,None
# 146,2017-01-07 08:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.85,51,16.9979,5.3471075307174685,None
# 147,2017-01-07 09:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,47,19.9995,4.897839799950911,None
# 148,2017-01-07 10:00:00,spring,No,Yes,Clear or partly cloudy,,9.85,37,22.0028,4.143134726391533,None
# 149,2017-01-07 11:00:00,spring,No,Yes,Mist,8.2,,40,15.0013,4.204692619390966,None
# 150,2017-01-07 12:00:00,spring,No,Yes,Mist,,9.85,37,16.9979,4.07753744390572,None
# 151,2017-01-07 13:00:00,spring,No,Yes,Mist,8.2,9.09,37,19.0012,4.290459441148391,None
# 152,2017-01-07 14:00:00,spring,No,Yes,Mist,8.2,9.85,40,16.9979,3.912023005428146,None
# 153,2017-01-07 15:00:00,spring,No,Yes,Mist,8.2,10.605,37,11.0014,4.276666119016055,None
# 154,2017-01-07 16:00:00,spring,No,Yes,Mist,,10.605,37,11.0014,4.465908118654584,None
# 155,2017-01-07 17:00:00,spring,No,Yes,Mist,8.2,12.88,37,0.0,5.231108616854587,None
# 156,2017-01-07 18:00:00,spring,No,Yes,Clear or partly cloudy,8.2,11.365,40,6.0032,4.812184355372417,None
# 157,2017-01-07 19:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.85,55,6.0032,4.553876891600541,None
# 158,2017-01-07 20:00:00,spring,No,Yes,Clear or partly cloudy,7.38,10.605,47,7.0015,3.9318256327243257,None
# 159,2017-01-07 21:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.85,47,8.9981,3.6635616461296463,None
# 160,2017-01-07 22:00:00,spring,No,Yes,Mist,7.38,9.85,43,11.0014,3.58351893845611,None
# 161,2017-01-07 23:00:00,spring,No,Yes,Mist,7.38,9.85,51,11.0014,2.70805020110221,None
# 162,2017-01-08 00:00:00,spring,No,No,Mist,7.38,9.85,51,11.0014,3.218875824868201,None
# 163,2017-01-08 01:00:00,spring,No,No,Mist,7.38,10.605,55,6.0032,2.772588722239781,None
# 164,2017-01-08 02:00:00,spring,No,No,Mist,7.38,12.12,55,0.0,2.772588722239781,None
# 165,2017-01-08 03:00:00,spring,No,No,Light snow or rain,7.38,9.85,55,11.0014,1.9459101490553132,None
# 166,2017-01-08 04:00:00,spring,No,No,Light snow or rain,7.38,9.85,55,11.0014,0.0,None
# 167,2017-01-08 05:00:00,spring,No,No,Mist,6.56,8.335,74,,1.6094379124341005,None
# 168,2017-01-08 06:00:00,spring,No,No,Mist,6.56,8.335,74,11.0014,0.6931471805599453,None
# 169,2017-01-08 07:00:00,spring,No,No,Mist,6.56,9.09,74,7.0015,2.1972245773362196,None
# 170,2017-01-08 08:00:00,spring,No,No,Light snow or rain,6.56,9.09,93,7.0015,2.70805020110221,None
# 171,2017-01-08 09:00:00,spring,No,No,Light snow or rain,6.56,9.09,93,7.0015,2.995732273553991,None
# 172,2017-01-08 10:00:00,spring,No,No,Mist,,9.85,80,11.0014,4.110873864173311,None
# 173,2017-01-08 11:00:00,spring,No,No,Mist,8.2,9.09,69,26.0027,4.127134385045092,None
# 174,2017-01-08 12:00:00,spring,No,No,Mist,8.2,9.09,59,23.9994,4.584967478670572,None
# 175,2017-01-08 13:00:00,spring,No,No,Clear or partly cloudy,8.2,9.09,44,22.0028,4.624972813284271,None
# 176,2017-01-08 14:00:00,spring,No,No,Clear or partly cloudy,8.2,8.335,32,32.9975,4.553876891600541,None
# 177,2017-01-08 15:00:00,spring,No,No,Clear or partly cloudy,8.2,8.335,32,30.0026,4.30406509320417,None
# 178,2017-01-08 16:00:00,spring,No,No,Clear or partly cloudy,7.38,6.82,29,30.0026,4.330733340286331,None
# 179,2017-01-08 17:00:00,spring,No,No,Clear or partly cloudy,6.56,6.06,37,36.9974,4.23410650459726,None
# 180,2017-01-08 18:00:00,spring,No,No,Clear or partly cloudy,5.74,6.06,39,19.9995,4.007333185232471,None
# 181,2017-01-08 19:00:00,spring,No,No,Clear or partly cloudy,5.74,6.06,36,16.9979,3.4011973816621555,None
# 182,2017-01-08 20:00:00,spring,No,No,Clear or partly cloudy,4.92,6.06,36,16.9979,3.332204510175204,None
# 183,2017-01-08 21:00:00,spring,No,No,Clear or partly cloudy,4.92,5.305,39,23.9994,3.610917912644224,None
# 184,2017-01-08 22:00:00,spring,No,No,Clear or partly cloudy,,5.305,36,26.0027,3.5263605246161616,None
# 185,2017-01-08 23:00:00,spring,No,No,Clear or partly cloudy,4.1,3.03,39,30.0026,3.091042453358316,None
# 186,2017-01-09 00:00:00,spring,No,No,Clear or partly cloudy,4.1,3.79,42,26.0027,3.218875824868201,None
# 187,2017-01-09 01:00:00,spring,No,No,Clear or partly cloudy,4.1,3.03,42,31.0009,2.4849066497880004,None
# 188,2017-01-09 02:00:00,spring,No,No,Clear or partly cloudy,4.1,3.03,46,31.0009,2.3978952727983707,None
# 189,2017-01-09 03:00:00,spring,No,No,Clear or partly cloudy,,3.79,46,27.9993,1.3862943611198906,None
# 190,2017-01-09 04:00:00,spring,No,No,Clear or partly cloudy,,4.545,53,12.998,0.0,None
# 191,2017-01-09 05:00:00,spring,No,No,Clear or partly cloudy,,4.545,53,12.998,0.0,None
# 192,2017-01-09 06:00:00,spring,No,No,Clear or partly cloudy,4.1,4.545,49,19.0012,0.0,None
# 193,2017-01-09 07:00:00,spring,No,No,Clear or partly cloudy,3.28,4.545,53,12.998,1.791759469228055,None
# 194,2017-01-09 08:00:00,spring,No,No,Clear or partly cloudy,4.1,4.545,49,19.0012,2.302585092994046,None
# 195,2017-01-09 09:00:00,spring,No,No,Clear or partly cloudy,4.92,3.79,46,35.0008,2.9444389791664403,None
# 196,2017-01-09 10:00:00,spring,No,No,Clear or partly cloudy,5.74,5.305,43,26.0027,3.8918202981106265,None
# 197,2017-01-09 11:00:00,spring,No,No,Clear or partly cloudy,6.56,6.06,40,35.0008,3.8918202981106265,None
# 198,2017-01-09 12:00:00,spring,No,No,Clear or partly cloudy,,6.82,37,30.0026,4.418840607796598,None
# 199,2017-01-09 13:00:00,spring,No,No,Clear or partly cloudy,8.2,8.335,34,30.0026,4.31748811353631,None
# 200,2017-01-09 14:00:00,spring,No,No,Clear or partly cloudy,9.02,9.09,32,31.0009,4.276666119016055,None
# 201,2017-01-09 15:00:00,spring,No,No,Clear or partly cloudy,9.02,9.85,35,23.9994,4.406719247264253,None
# 202,2017-01-09 16:00:00,spring,No,No,Clear or partly cloudy,8.2,8.335,34,30.0026,4.5217885770490405,None
# 203,2017-01-09 17:00:00,spring,No,No,Clear or partly cloudy,7.38,7.575,37,26.0027,4.127134385045092,None
# 204,2017-01-09 18:00:00,spring,No,No,Clear or partly cloudy,6.56,6.82,40,,3.871201010907891,None
# 205,2017-01-09 19:00:00,spring,No,No,Clear or partly cloudy,6.56,6.82,43,22.0028,3.713572066704308,None
# 206,2017-01-09 20:00:00,spring,No,No,Clear or partly cloudy,,6.06,46,16.9979,3.6375861597263857,None
# 207,2017-01-09 21:00:00,spring,No,No,Clear or partly cloudy,5.74,5.305,46,27.9993,2.995732273553991,None
# 208,2017-01-09 22:00:00,spring,No,No,Clear or partly cloudy,5.74,6.06,46,19.9995,2.70805020110221,None
# 209,2017-01-09 23:00:00,spring,No,No,Clear or partly cloudy,4.92,6.82,50,12.998,1.791759469228055,None
# 210,2017-01-10 00:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.06,50,19.0012,1.6094379124341005,None
# 211,2017-01-10 01:00:00,spring,No,Yes,Clear or partly cloudy,,6.06,50,19.0012,0.0,None
# 212,2017-01-10 02:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.06,50,15.0013,1.0986122886681098,None
# 213,2017-01-10 03:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.06,50,15.0013,0.0,None
# 214,2017-01-10 04:00:00,spring,No,Yes,Clear or partly cloudy,4.1,6.06,54,8.9981,1.0986122886681098,None
# 215,2017-01-10 05:00:00,spring,No,Yes,Clear or partly cloudy,4.1,5.305,54,16.9979,1.0986122886681098,None
# 216,2017-01-10 06:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.06,50,19.0012,3.4339872044851463,None
# 217,2017-01-10 07:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.06,50,15.0013,4.343805421853684,None
# 218,2017-01-10 08:00:00,spring,No,Yes,Mist,4.92,6.06,50,19.0012,5.236441962829949,None
# 219,2017-01-10 09:00:00,spring,No,Yes,Mist,5.74,6.06,50,,4.543294782270004,None
# 220,2017-01-10 10:00:00,spring,No,Yes,Mist,5.74,6.06,50,19.9995,3.4339872044851463,None
# 221,2017-01-10 11:00:00,spring,No,Yes,Mist,6.56,6.82,47,19.0012,3.4011973816621555,None
# 222,2017-01-10 12:00:00,spring,No,Yes,Mist,8.2,9.09,40,19.0012,3.951243718581427,None
# 223,2017-01-10 13:00:00,spring,No,Yes,Mist,8.2,9.09,40,19.0012,3.9889840465642745,None
# 224,2017-01-10 14:00:00,spring,No,Yes,Mist,,9.85,40,15.0013,3.8501476017100584,None
# 225,2017-01-10 15:00:00,spring,No,Yes,Mist,8.2,9.85,40,15.0013,3.80666248977032,None
# 226,2017-01-10 16:00:00,spring,No,Yes,Clear or partly cloudy,8.2,10.605,40,8.9981,4.30406509320417,None
# 227,2017-01-10 17:00:00,spring,No,Yes,Clear or partly cloudy,8.2,11.365,40,7.0015,5.181783550292085,None
# 228,2017-01-10 18:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.85,40,15.0013,5.043425116919247,None
# 229,2017-01-10 19:00:00,spring,No,Yes,Clear or partly cloudy,6.56,8.335,47,11.0014,4.553876891600541,None
# 230,2017-01-10 20:00:00,spring,No,Yes,Clear or partly cloudy,6.56,8.335,50,11.0014,4.30406509320417,None
# 231,2017-01-10 21:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.82,59,12.998,3.6375861597263857,None
# 232,2017-01-10 22:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,59,11.0014,3.1780538303479458,None
# 233,2017-01-10 23:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,59,11.0014,2.8903717578961645,None
# 234,2017-01-11 00:00:00,spring,No,Yes,Clear or partly cloudy,5.74,8.335,59,7.0015,2.4849066497880004,None
# 235,2017-01-11 01:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,59,11.0014,1.0986122886681098,None
# 236,2017-01-11 02:00:00,spring,No,Yes,Mist,6.56,7.575,55,12.998,1.0986122886681098,None
# 237,2017-01-11 05:00:00,spring,No,Yes,Mist,6.56,9.09,55,8.9981,1.791759469228055,None
# 238,2017-01-11 06:00:00,spring,No,Yes,Mist,6.56,9.09,55,8.9981,3.295836866004329,None
# 239,2017-01-11 07:00:00,spring,No,Yes,Mist,,11.365,55,0.0,4.59511985013459,None
# 240,2017-01-11 08:00:00,spring,No,Yes,Mist,7.38,10.605,51,6.0032,5.37989735354046,None
# 241,2017-01-11 09:00:00,spring,No,Yes,Mist,7.38,9.85,51,11.0014,4.867534450455582,None
# 242,2017-01-11 10:00:00,spring,No,Yes,Mist,8.2,10.605,51,11.0014,3.9889840465642745,None
# 243,2017-01-11 11:00:00,spring,No,Yes,Mist,8.2,10.605,47,8.9981,3.5553480614894135,None
# 244,2017-01-11 12:00:00,spring,No,Yes,Mist,8.2,11.365,51,7.0015,4.04305126783455,None
# 245,2017-01-11 13:00:00,spring,No,Yes,Mist,8.2,11.365,59,6.0032,3.951243718581427,None
# 246,2017-01-11 14:00:00,spring,No,Yes,Mist,8.2,11.365,59,6.0032,4.143134726391533,None
# 247,2017-01-11 15:00:00,spring,No,Yes,Mist,6.56,9.85,80,6.0032,3.8501476017100584,None
# 248,2017-01-11 16:00:00,spring,No,Yes,Mist,6.56,7.575,86,15.0013,4.330733340286331,None
# 249,2017-01-11 17:00:00,spring,No,Yes,Mist,6.56,7.575,86,15.0013,4.912654885736052,None
# 250,2017-01-11 18:00:00,spring,No,Yes,Light snow or rain,6.56,9.09,93,7.0015,4.553876891600541,None
# 251,2017-01-11 19:00:00,spring,No,Yes,Light snow or rain,6.56,11.365,93,0.0,3.9318256327243257,None
# 252,2017-01-11 20:00:00,spring,No,Yes,Light snow or rain,6.56,7.575,93,12.998,3.4657359027997265,None
# 253,2017-01-11 21:00:00,spring,No,Yes,Light snow or rain,6.56,9.85,86,6.0032,2.995732273553991,None
# 254,2017-01-11 22:00:00,spring,No,Yes,Light snow or rain,6.56,9.09,93,7.0015,3.367295829986474,None
# 255,2017-01-11 23:00:00,spring,No,Yes,Light snow or rain,6.56,9.85,93,6.0032,2.9444389791664403,None
# 256,2017-01-12 00:00:00,spring,No,Yes,Mist,6.56,9.85,86,6.0032,1.9459101490553132,None
# 257,2017-01-12 01:00:00,spring,No,Yes,Mist,6.56,9.09,86,7.0015,1.791759469228055,None
# 258,2017-01-12 02:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,86,8.9981,0.0,None
# 259,2017-01-12 05:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,86,11.0014,1.6094379124341005,None
# 260,2017-01-12 06:00:00,spring,No,Yes,Clear or partly cloudy,4.92,7.575,93,8.9981,2.772588722239781,None
# 261,2017-01-12 07:00:00,spring,No,Yes,Clear or partly cloudy,,7.575,69,8.9981,3.9889840465642745,None
# 262,2017-01-12 08:00:00,spring,No,Yes,Clear or partly cloudy,6.56,8.335,59,11.0014,4.852030263919617,None
# 263,2017-01-12 09:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,59,22.0028,4.394449154672439,None
# 264,2017-01-12 10:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.09,55,15.0013,3.6635616461296463,None
# 265,2017-01-12 11:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,51,26.0027,3.5553480614894135,None
# 266,2017-01-12 12:00:00,spring,No,Yes,Clear or partly cloudy,8.2,7.575,47,39.0007,4.007333185232471,None
# 267,2017-01-12 13:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,44,23.9994,3.8918202981106265,None
# 268,2017-01-12 14:00:00,spring,No,Yes,Clear or partly cloudy,,9.09,47,22.0028,3.784189633918261,None
# 269,2017-01-12 15:00:00,spring,No,Yes,Clear or partly cloudy,8.2,8.335,47,27.9993,3.8918202981106265,None
# 270,2017-01-12 16:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,44,22.0028,4.219507705176107,None
# 271,2017-01-12 17:00:00,spring,No,Yes,Clear or partly cloudy,,9.09,47,23.9994,4.9344739331306915,None
# 272,2017-01-12 18:00:00,spring,No,Yes,Clear or partly cloudy,8.2,7.575,47,35.0008,4.919980925828125,None
# 273,2017-01-12 19:00:00,spring,No,Yes,Clear or partly cloudy,7.38,7.575,47,27.9993,4.418840607796598,None
# 274,2017-01-12 20:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,50,22.0028,4.02535169073515,None
# 275,2017-01-12 21:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,55,22.0028,4.04305126783455,None
# 276,2017-01-12 22:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.06,55,30.0026,3.49650756146648,None
# 277,2017-01-12 23:00:00,spring,No,Yes,Clear or partly cloudy,,5.305,59,27.9993,2.995732273553991,None
# 278,2017-01-13 00:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,59,19.0012,1.9459101490553132,None
# 279,2017-01-13 01:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,19.0012,0.6931471805599453,None
# 280,2017-01-13 02:00:00,spring,No,Yes,Clear or partly cloudy,,6.06,50,23.9994,0.6931471805599453,None
# 281,2017-01-13 03:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,22.0028,1.0986122886681098,None
# 282,2017-01-13 04:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,16.9979,1.3862943611198906,None
# 283,2017-01-13 05:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,19.9995,1.0986122886681098,None
# 284,2017-01-13 06:00:00,spring,No,Yes,Clear or partly cloudy,,7.575,54,8.9981,3.332204510175204,None
# 285,2017-01-13 07:00:00,spring,No,Yes,Clear or partly cloudy,4.92,7.575,54,8.9981,4.276666119016055,None
# 286,2017-01-13 08:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.82,50,12.998,5.308267697401205,None
# 287,2017-01-13 09:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,22.0028,4.9344739331306915,None
# 288,2017-01-13 10:00:00,spring,No,Yes,Mist,6.56,6.82,50,23.9994,3.6375861597263857,None
# 289,2017-01-13 11:00:00,spring,No,Yes,Mist,8.2,8.335,44,30.0026,3.610917912644224,None
# 290,2017-01-13 12:00:00,spring,No,Yes,Clear or partly cloudy,8.2,,44,27.9993,3.951243718581427,None
# 291,2017-01-13 13:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,41,30.0026,4.418840607796598,None
# 292,2017-01-13 14:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,41,26.0027,3.737669618283368,None
# 293,2017-01-13 15:00:00,spring,No,Yes,Clear or partly cloudy,,10.605,38,19.9995,4.0943445622221,None
# 294,2017-01-13 16:00:00,spring,No,Yes,Clear or partly cloudy,9.84,10.605,38,23.9994,4.356708826689592,None
# 295,2017-01-13 17:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,40,19.0012,5.087596335232384,None
# 296,2017-01-13 18:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,40,22.0028,4.969813299576001,None
# 297,2017-01-13 19:00:00,spring,No,Yes,Clear or partly cloudy,6.56,7.575,47,16.9979,4.59511985013459,None
# 298,2017-01-13 20:00:00,spring,No,Yes,Clear or partly cloudy,6.56,7.575,47,15.0013,4.1588830833596715,None
# 299,2017-01-13 21:00:00,spring,No,Yes,Clear or partly cloudy,,6.06,46,19.9995,3.688879454113936,None
# 300,2017-01-13 22:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,46,22.0028,3.4011973816621555,None
# 301,2017-01-13 23:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.82,50,12.998,2.70805020110221,None
# 302,2017-01-14 00:00:00,spring,No,Yes,Clear or partly cloudy,4.92,6.82,50,12.998,2.6390573296152584,None
# 303,2017-01-14 01:00:00,spring,No,Yes,Clear or partly cloudy,4.1,6.06,54,11.0014,1.6094379124341005,None
# 304,2017-01-14 02:00:00,spring,No,Yes,Clear or partly cloudy,4.1,,54,8.9981,0.0,None
# 305,2017-01-14 03:00:00,spring,No,Yes,Clear or partly cloudy,4.1,6.82,54,7.0015,0.0,None
# 306,2017-01-14 05:00:00,spring,No,Yes,Clear or partly cloudy,4.1,6.82,54,6.0032,2.0794415416798357,None
# 307,2017-01-14 06:00:00,spring,No,Yes,Clear or partly cloudy,,9.09,54,0.0,2.833213344056216,None
# 308,2017-01-14 07:00:00,spring,No,Yes,Clear or partly cloudy,4.1,6.06,74,11.0014,4.248495242049359,None
# 309,2017-01-14 08:00:00,spring,No,Yes,Clear or partly cloudy,4.92,8.335,68,0.0,5.062595033026967,None
# 310,2017-01-14 09:00:00,spring,No,Yes,Clear or partly cloudy,5.74,7.575,69,8.9981,4.762173934797756,None
# 311,2017-01-14 10:00:00,spring,No,Yes,Clear or partly cloudy,7.38,9.09,55,12.998,3.784189633918261,None
# 312,2017-01-14 11:00:00,spring,No,Yes,Clear or partly cloudy,7.38,8.335,51,19.0012,3.970291913552122,None
# 313,2017-01-14 12:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.85,44,16.9979,4.110873864173311,None
# 314,2017-01-14 13:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,37,26.0027,4.343805421853684,None
# 315,2017-01-14 14:00:00,spring,No,Yes,Clear or partly cloudy,9.02,10.605,41,19.0012,4.1588830833596715,None
# 316,2017-01-14 15:00:00,spring,No,Yes,Clear or partly cloudy,9.84,12.12,38,11.0014,4.219507705176107,None
# 317,2017-01-14 16:00:00,spring,No,Yes,Clear or partly cloudy,9.02,12.12,41,7.0015,4.499809670330265,None
# 318,2017-01-14 17:00:00,spring,No,Yes,Clear or partly cloudy,9.02,11.365,41,11.0014,5.0689042022202315,None
# 319,2017-01-14 18:00:00,spring,No,Yes,Clear or partly cloudy,8.2,12.88,47,0.0,4.9344739331306915,None
# 320,2017-01-14 19:00:00,spring,No,Yes,Clear or partly cloudy,6.56,9.85,59,6.0032,4.5217885770490405,None
# 321,2017-01-14 20:00:00,spring,No,Yes,Clear or partly cloudy,7.38,12.12,59,0.0,4.219507705176107,None
# 322,2017-01-14 21:00:00,spring,No,Yes,Clear or partly cloudy,6.56,11.365,69,0.0,3.951243718581427,None
# 323,2017-01-14 22:00:00,spring,No,Yes,Mist,,11.365,69,0.0,3.58351893845611,None
# 324,2017-01-14 23:00:00,spring,No,Yes,Mist,7.38,12.12,55,0.0,3.295836866004329,None
# 325,2017-01-15 00:00:00,spring,No,No,Clear or partly cloudy,,12.12,55,0.0,3.332204510175204,None
# 326,2017-01-15 01:00:00,spring,No,No,Mist,6.56,9.85,59,6.0032,2.995732273553991,None
# 327,2017-01-15 02:00:00,spring,No,No,Mist,6.56,9.85,59,6.0032,2.4849066497880004,None
# 328,2017-01-15 03:00:00,spring,No,No,Mist,6.56,11.365,59,0.0,2.0794415416798357,None
# 329,2017-01-15 04:00:00,spring,No,No,Mist,6.56,11.365,59,0.0,1.6094379124341005,None
# 330,2017-01-15 05:00:00,spring,No,No,Clear or partly cloudy,6.56,11.365,59,0.0,0.0,None
# 331,2017-01-15 06:00:00,spring,No,No,Clear or partly cloudy,5.74,8.335,,7.0015,1.0986122886681098,None
# 332,2017-01-15 07:00:00,spring,No,No,Clear or partly cloudy,5.74,10.605,63,0.0,2.302585092994046,None
# 333,2017-01-15 08:00:00,spring,No,No,Clear or partly cloudy,,7.575,63,8.9981,3.1354942159291497,None
# 334,2017-01-15 09:00:00,spring,No,No,Clear or partly cloudy,6.56,9.09,64,8.9981,3.49650756146648,None
# 335,2017-01-15 10:00:00,spring,No,No,Clear or partly cloudy,7.38,9.85,59,11.0014,4.07753744390572,None
# 336,2017-01-15 11:00:00,spring,No,No,Clear or partly cloudy,8.2,9.85,55,15.0013,4.276666119016055,None
# 337,2017-01-15 12:00:00,spring,No,No,Clear or partly cloudy,9.84,11.365,48,15.0013,4.48863636973214,None
# 338,2017-01-15 13:00:00,spring,No,No,Clear or partly cloudy,11.48,12.88,38,19.9995,4.61512051684126,None
# 339,2017-01-15 14:00:00,spring,No,No,Clear or partly cloudy,,14.395,39,19.0012,4.770684624465665,None
# 340,2017-01-15 15:00:00,spring,No,No,Mist,13.12,15.91,36,12.998,4.859812404361672,None
# 341,2017-01-15 16:00:00,spring,No,No,Mist,13.94,16.665,34,12.998,4.852030263919617,None
# 342,2017-01-15 17:00:00,spring,No,No,Mist,13.12,15.15,36,19.0012,4.418840607796598,None
# 343,2017-01-15 18:00:00,spring,No,No,Mist,12.3,14.395,45,16.9979,4.430816798843313,None
# 344,2017-01-15 19:00:00,spring,No,No,Mist,13.12,15.15,39,16.9979,4.30406509320417,None
# 345,2017-01-15 20:00:00,spring,No,No,Mist,13.12,15.15,39,16.9979,3.713572066704308,None
# 346,2017-01-15 21:00:00,spring,No,No,Mist,13.12,15.15,39,15.0013,4.04305126783455,None
# 347,2017-01-15 22:00:00,spring,No,No,Mist,,15.91,42,7.0015,3.258096538021482,None
# 348,2017-01-15 23:00:00,spring,No,No,Clear or partly cloudy,12.3,14.395,45,19.0012,3.784189633918261,None
# 349,2017-01-16 00:00:00,spring,No,No,Clear or partly cloudy,10.66,15.15,56,0.0,3.6635616461296463,None
# 350,2017-01-16 01:00:00,spring,No,No,Clear or partly cloudy,10.66,13.635,56,8.9981,3.1354942159291497,None
# 351,2017-01-16 02:00:00,spring,No,No,Clear or partly cloudy,10.66,14.395,56,6.0032,2.772588722239781,None
# 352,2017-01-16 03:00:00,spring,No,No,Clear or partly cloudy,9.02,13.635,69,0.0,2.70805020110221,None
# 353,2017-01-16 04:00:00,spring,No,No,Clear or partly cloudy,10.66,12.88,56,11.0014,0.0,None
# 354,2017-01-16 05:00:00,spring,No,No,Mist,10.66,12.88,56,11.0014,0.6931471805599453,None
# 355,2017-01-16 06:00:00,spring,No,No,Mist,10.66,12.88,56,11.0014,0.0,None
# 356,2017-01-16 07:00:00,spring,No,No,Mist,9.84,10.605,56,19.9995,1.0986122886681098,None
# 357,2017-01-16 08:00:00,spring,No,No,Clear or partly cloudy,9.02,10.605,55,19.0012,2.8903717578961645,None
# 358,2017-01-16 09:00:00,spring,No,No,Clear or partly cloudy,9.02,10.605,51,16.9979,3.4657359027997265,None
# 359,2017-01-16 10:00:00,spring,No,No,Clear or partly cloudy,9.02,10.605,51,19.0012,4.3694478524670215,None
# 360,2017-01-16 11:00:00,spring,No,No,Clear or partly cloudy,9.84,11.365,44,16.9979,4.532599493153256,None
# 361,2017-01-16 12:00:00,spring,No,No,Clear or partly cloudy,,10.605,41,19.0012,4.6443908991413725,None
# 362,2017-01-16 13:00:00,spring,No,No,Clear or partly cloudy,10.66,11.365,35,19.9995,4.770684624465665,None
# 363,2017-01-16 14:00:00,spring,No,No,Clear or partly cloudy,11.48,13.635,36,16.9979,4.51085950651685,None
# 364,2017-01-16 15:00:00,spring,No,No,Clear or partly cloudy,10.66,12.12,38,16.9979,4.727387818712341,None
# 365,2017-01-16 16:00:00,spring,No,No,Clear or partly cloudy,9.84,11.365,38,15.0013,4.59511985013459,None
# 366,2017-01-16 17:00:00,spring,No,No,Clear or partly cloudy,,10.605,37,16.9979,4.653960350157523,None
# 367,2017-01-16 18:00:00,spring,No,No,Clear or partly cloudy,,10.605,40,11.0014,4.204692619390966,None
# 368,2017-01-16 19:00:00,spring,No,No,Clear or partly cloudy,7.38,9.85,47,8.9981,4.110873864173311,None
# 369,2017-01-16 20:00:00,spring,No,No,Clear or partly cloudy,7.38,9.85,47,11.0014,4.04305126783455,None
# 370,2017-01-16 21:00:00,spring,No,No,Clear or partly cloudy,7.38,9.85,51,11.0014,3.332204510175204,None
# 371,2017-01-16 22:00:00,spring,No,No,Mist,8.2,10.605,49,,3.044522437723423,None
# 372,2017-01-16 23:00:00,spring,No,No,Mist,8.2,11.365,40,7.0015,2.8903717578961645,None
# 373,2017-01-17 00:00:00,spring,Yes,No,Mist,8.2,9.85,47,15.0013,2.833213344056216,None
# 374,2017-01-17 01:00:00,spring,Yes,No,Mist,,9.85,44,12.998,2.772588722239781,None
# 375,2017-01-17 02:00:00,spring,Yes,No,Mist,7.38,8.335,43,,2.0794415416798357,None
# 376,2017-01-17 03:00:00,spring,Yes,No,Mist,,9.09,43,12.998,0.6931471805599453,None
# 377,2017-01-17 04:00:00,spring,Yes,No,Mist,7.38,9.85,43,8.9981,1.0986122886681098,None
# 378,2017-01-17 05:00:00,spring,Yes,No,Mist,7.38,9.85,43,11.0014,0.0,None
# 379,2017-01-17 06:00:00,spring,Yes,No,Mist,7.38,9.09,43,12.998,1.6094379124341005,None
# 380,2017-01-17 07:00:00,spring,Yes,No,Mist,6.56,9.09,50,8.9981,2.5649493574615367,None
# 381,2017-01-17 08:00:00,spring,Yes,No,Mist,,7.575,47,15.0013,3.49650756146648,None
# 382,2017-01-17 09:00:00,spring,Yes,No,Mist,6.56,7.575,47,15.0013,3.8501476017100584,None
# 383,2017-01-17 10:00:00,spring,Yes,No,Mist,6.56,7.575,50,16.9979,4.04305126783455,None
# 384,2017-01-17 11:00:00,spring,Yes,No,Mist,6.56,7.575,55,12.998,4.1588830833596715,None
# 385,2017-01-17 12:00:00,spring,Yes,No,Mist,7.38,9.85,47,8.9981,4.382026634673881,None
# 386,2017-01-17 13:00:00,spring,Yes,No,Mist,7.38,9.85,47,8.9981,4.532599493153256,None
# 387,2017-01-17 14:00:00,spring,Yes,No,Mist,7.38,10.605,43,7.0015,4.454347296253507,None
# 388,2017-01-17 15:00:00,spring,Yes,No,Mist,8.2,10.605,47,11.0014,4.532599493153256,None
# 389,2017-01-17 16:00:00,spring,Yes,No,Mist,8.2,10.605,47,11.0014,4.406719247264253,None
# 390,2017-01-17 17:00:00,spring,Yes,No,Clear or partly cloudy,,9.85,51,12.998,4.2626798770413155,None
# 391,2017-01-17 18:00:00,spring,Yes,No,Mist,7.38,8.335,55,16.9979,4.5217885770490405,None
# 392,2017-01-17 19:00:00,spring,Yes,No,Light snow or rain,7.38,9.09,59,12.998,4.0943445622221,None
# 393,2017-01-17 20:00:00,spring,Yes,No,Light snow or rain,,7.575,80,12.998,3.49650756146648,None
# 394,2017-01-17 21:00:00,spring,Yes,No,Light snow or rain,6.56,7.575,80,12.998,3.295836866004329,None
# 395,2017-01-17 22:00:00,spring,Yes,No,Light snow or rain,5.74,6.06,93,16.9979,2.5649493574615367,None
# 396,2017-01-17 23:00:00,spring,Yes,No,Light snow or rain,,6.82,86,19.0012,1.3862943611198906,None
# 397,2017-01-18 12:00:00,spring,No,Yes,Mist,,9.09,86,22.0028,1.0986122886681098,None
# 398,2017-01-18 13:00:00,spring,No,Yes,Mist,8.2,9.85,86,15.0013,3.091042453358316,None
# 399,2017-01-18 14:00:00,spring,No,Yes,Mist,9.02,11.365,80,11.0014,3.332204510175204,None
# 400,2017-01-18 15:00:00,spring,No,Yes,Mist,,11.365,87,11.0014,3.5553480614894135,None
# 401,2017-01-18 16:00:00,spring,No,Yes,Mist,,11.365,87,12.998,4.110873864173311,None
# 402,2017-01-18 17:00:00,spring,No,Yes,Mist,9.02,11.365,82,12.998,4.8283137373023015,None
# 403,2017-01-18 18:00:00,spring,No,Yes,Mist,9.02,11.365,80,11.0014,4.890349128221754,None
# 404,2017-01-18 19:00:00,spring,No,Yes,Mist,9.02,11.365,80,8.9981,4.59511985013459,None
# 405,2017-01-18 20:00:00,spring,No,Yes,Mist,9.02,13.635,87,0.0,4.418840607796598,None
# 406,2017-01-18 21:00:00,spring,No,Yes,Mist,9.02,12.12,93,7.0015,3.713572066704308,None
# 407,2017-01-18 22:00:00,spring,No,Yes,Mist,9.02,12.88,93,6.0032,3.49650756146648,None
# 408,2017-01-18 23:00:00,spring,No,Yes,Mist,9.02,13.635,93,0.0,2.995732273553991,None
# 409,2017-01-19 00:00:00,spring,No,Yes,Mist,9.02,13.635,93,0.0,1.0986122886681098,None
# 410,2017-01-19 01:00:00,spring,No,Yes,Light snow or rain,,11.365,93,8.9981,1.9459101490553132,None
# 411,2017-01-19 02:00:00,spring,No,Yes,Light snow or rain,9.02,11.365,93,8.9981,1.0986122886681098,None
# 412,2017-01-19 04:00:00,spring,No,Yes,Light snow or rain,9.02,11.365,93,8.9981,0.6931471805599453,None
# 413,2017-01-19 05:00:00,spring,No,Yes,Mist,9.02,12.88,93,6.0032,1.9459101490553132,None
# 414,2017-01-19 06:00:00,spring,No,Yes,Mist,9.02,12.88,93,6.0032,3.4657359027997265,None
# 415,2017-01-19 07:00:00,spring,No,Yes,Mist,9.84,12.88,92,7.0015,4.499809670330265,None
# 416,2017-01-19 08:00:00,spring,No,Yes,Mist,,12.88,93,7.0015,5.2832037287379885,None
# 417,2017-01-19 09:00:00,spring,No,Yes,Mist,9.84,12.88,93,7.0015,4.6913478822291435,None
# 418,2017-01-19 10:00:00,spring,No,Yes,Mist,10.66,13.635,93,8.9981,3.8501476017100584,None
# 419,2017-01-19 11:00:00,spring,No,Yes,Mist,11.48,15.15,87,6.0032,3.951243718581427,None
# 420,2017-01-19 12:00:00,spring,No,Yes,Mist,12.3,15.91,81,6.0032,4.248495242049359,None
# 421,2017-01-19 13:00:00,spring,No,Yes,Clear or partly cloudy,16.4,,62,19.0012,4.356708826689592,None
# 422,2017-01-19 14:00:00,spring,No,Yes,Clear or partly cloudy,16.4,20.455,58,16.9979,4.31748811353631,None
# 423,2017-01-19 15:00:00,spring,No,Yes,Clear or partly cloudy,,20.455,54,19.0012,4.406719247264253,None
# 424,2017-01-19 16:00:00,spring,No,Yes,Clear or partly cloudy,15.58,19.695,58,26.0027,4.6443908991413725,None
# 425,2017-01-19 17:00:00,spring,No,Yes,Clear or partly cloudy,14.76,16.665,57,22.0028,5.2832037287379885,None
# 426,2017-01-19 18:00:00,spring,No,Yes,Clear or partly cloudy,13.94,15.91,61,19.0012,5.081404364984463,None
# 427,2017-01-19 19:00:00,spring,No,Yes,Clear or partly cloudy,13.12,14.395,57,27.9993,4.718498871295094,None
# 428,2017-01-19 20:00:00,spring,No,Yes,Clear or partly cloudy,13.12,15.15,49,19.9995,4.330733340286331,None
# 429,2017-01-19 21:00:00,spring,No,Yes,Clear or partly cloudy,13.12,14.395,49,27.9993,4.07753744390572,None
# 430,2017-01-19 22:00:00,spring,No,Yes,Clear or partly cloudy,12.3,15.15,52,11.0014,4.07753744390572,None
# 431,2017-01-19 23:00:00,spring,No,Yes,Clear or partly cloudy,12.3,13.635,52,31.0009,3.332204510175204,None
# 432,2017-02-01 00:00:00,spring,No,Yes,Mist,6.56,9.09,64,7.0015,2.0794415416798357,None
# 433,2017-02-01 01:00:00,spring,No,Yes,Mist,6.56,9.09,69,7.0015,1.0986122886681098,None
# 434,2017-02-01 02:00:00,spring,No,Yes,Mist,6.56,11.365,69,0.0,0.6931471805599453,None
# 435,2017-02-01 03:00:00,spring,No,Yes,Mist,6.56,11.365,69,0.0,0.6931471805599453,None
# 436,2017-02-01 05:00:00,spring,No,Yes,Light snow or rain,5.74,10.605,93,0.0,1.0986122886681098,None
# 437,2017-02-01 06:00:00,spring,No,Yes,Light snow or rain,5.74,10.605,93,0.0,3.091042453358316,None
# 438,2017-02-01 07:00:00,spring,No,Yes,Light snow or rain,6.56,11.365,93,0.0,3.951243718581427,None
# 439,2017-02-01 08:00:00,spring,No,Yes,Light snow or rain,6.56,11.365,93,0.0,4.90527477843843,None
# 440,2017-02-01 09:00:00,spring,No,Yes,Mist,6.56,11.365,93,0.0,4.7535901911063645,None
# 441,2017-02-01 10:00:00,spring,No,Yes,Mist,6.56,11.365,93,0.0,3.8501476017100584,None
# 442,2017-02-01 11:00:00,spring,No,Yes,Mist,,12.12,86,0.0,3.9318256327243257,None
# 443,2017-02-01 12:00:00,spring,No,Yes,Mist,8.2,12.88,86,0.0,4.007333185232471,None
# 444,2017-02-01 13:00:00,spring,No,Yes,Mist,8.2,12.88,86,0.0,3.951243718581427,None
# 445,2017-02-01 14:00:00,spring,No,Yes,Mist,9.02,12.88,80,6.0032,3.9889840465642745,None
# 446,2017-02-01 15:00:00,spring,No,Yes,Mist,9.84,14.395,75,,3.951243718581427,None
# 447,2017-02-01 16:00:00,spring,No,Yes,Mist,9.84,12.12,75,8.9981,4.1588830833596715,None
# 448,2017-02-01 17:00:00,spring,No,Yes,Mist,9.84,14.395,75,0.0,5.170483995038151,None
# 449,2017-02-01 18:00:00,spring,No,Yes,Mist,9.84,12.88,81,7.0015,5.123963979403259,None
# 450,2017-02-01 19:00:00,spring,No,Yes,Mist,9.84,12.12,81,8.9981,4.68213122712422,None
# 451,2017-02-01 20:00:00,spring,No,Yes,Mist,9.02,11.365,87,8.9981,4.30406509320417,None
# 452,2017-02-01 21:00:00,spring,No,Yes,Mist,,11.365,87,8.9981,4.1588830833596715,None
# 453,2017-02-01 22:00:00,spring,No,Yes,Mist,9.02,12.88,87,6.0032,3.58351893845611,None
# 454,2017-02-01 23:00:00,spring,No,Yes,Light snow or rain,8.2,9.85,93,12.998,2.772588722239781,None
# 455,2017-02-02 00:00:00,spring,No,Yes,Light snow or rain,9.02,12.12,93,7.0015,0.6931471805599453,None
# 456,2017-02-02 01:00:00,spring,No,Yes,Light snow or rain,9.02,11.365,93,12.998,1.0986122886681098,None
# 457,2017-02-02 02:00:00,spring,No,Yes,Light snow or rain,9.02,11.365,93,8.9981,1.3862943611198906,None
# 458,2017-02-02 03:00:00,spring,No,Yes,Light snow or rain,,11.365,93,8.9981,0.0,None
# 459,2017-02-02 04:00:00,spring,No,Yes,Light snow or rain,9.02,10.605,93,19.0012,0.0,None
# 460,2017-02-02 05:00:00,spring,No,Yes,Light snow or rain,9.02,12.12,93,7.0015,1.0986122886681098,None
# 461,2017-02-02 06:00:00,spring,No,Yes,Light snow or rain,9.02,12.12,93,7.0015,2.8903717578961645,None
# 462,2017-02-02 07:00:00,spring,No,Yes,Light snow or rain,9.02,10.605,93,15.0013,3.8918202981106265,None
# 463,2017-02-02 08:00:00,spring,No,Yes,Light snow or rain,9.02,10.605,93,15.0013,5.043425116919247,None
# 464,2017-02-02 09:00:00,spring,No,Yes,Mist,9.84,12.88,93,6.0032,4.812184355372417,None
# 465,2017-02-02 10:00:00,spring,No,Yes,Mist,9.02,13.635,100,0.0,4.110873864173311,None
# 466,2017-02-02 11:00:00,spring,No,Yes,Mist,9.84,11.365,93,12.998,3.951243718581427,None
# 467,2017-02-02 12:00:00,spring,No,Yes,Mist,9.84,11.365,93,15.0013,4.1588830833596715,None
# 468,2017-02-02 13:00:00,spring,No,Yes,Clear or partly cloudy,13.94,16.665,93,11.0014,4.31748811353631,None
# 469,2017-02-02 14:00:00,spring,No,Yes,Clear or partly cloudy,15.58,19.695,82,26.0027,4.143134726391533,None
# 470,2017-02-02 15:00:00,spring,No,Yes,Clear or partly cloudy,15.58,19.695,76,22.0028,4.330733340286331,None
# 471,2017-02-02 16:00:00,spring,No,Yes,Clear or partly cloudy,14.76,16.665,71,19.9995,4.634728988229636,None
# 472,2017-02-02 17:00:00,spring,No,Yes,Clear or partly cloudy,,15.91,53,35.0008,5.247024072160486,None
# 473,2017-02-02 18:00:00,spring,No,Yes,Clear or partly cloudy,13.94,14.395,42,36.9974,5.204006687076795,None
# 474,2017-02-02 19:00:00,spring,No,Yes,Clear or partly cloudy,11.48,12.12,45,32.9975,4.51085950651685,None
# 475,2017-02-02 20:00:00,spring,No,Yes,Clear or partly cloudy,9.84,9.85,48,36.9974,4.31748811353631,None
# 476,2017-02-02 21:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,47,22.0028,4.143134726391533,None
# 477,2017-02-02 22:00:00,spring,No,Yes,Clear or partly cloudy,9.02,10.605,44,16.9979,3.688879454113936,None
# 478,2017-02-02 23:00:00,spring,No,Yes,Clear or partly cloudy,8.2,8.335,44,30.0026,3.4657359027997265,None
# 479,2017-02-03 00:00:00,spring,No,Yes,Clear or partly cloudy,8.2,8.335,40,30.0026,2.4849066497880004,None
# 480,2017-02-03 01:00:00,spring,No,Yes,Clear or partly cloudy,,7.575,44,35.0008,1.6094379124341005,None
# 481,2017-02-03 02:00:00,spring,No,Yes,Clear or partly cloudy,7.38,8.335,43,16.9979,0.6931471805599453,None
# 482,2017-02-03 03:00:00,spring,No,Yes,Clear or partly cloudy,7.38,8.335,43,16.9979,0.0,None
# 483,2017-02-03 05:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,50,19.9995,0.6931471805599453,None
# 484,2017-02-03 06:00:00,spring,No,Yes,Clear or partly cloudy,,6.82,43,23.9994,3.6635616461296463,None
# 485,2017-02-03 07:00:00,spring,No,Yes,Clear or partly cloudy,,6.06,50,22.0028,4.465908118654584,None
# 486,2017-02-03 08:00:00,spring,No,Yes,Clear or partly cloudy,5.74,6.06,50,23.9994,5.236441962829949,None
# 487,2017-02-03 09:00:00,spring,No,Yes,Clear or partly cloudy,6.56,6.82,47,,4.890349128221754,None
# 488,2017-02-03 10:00:00,spring,No,Yes,Clear or partly cloudy,7.38,7.575,43,22.0028,3.951243718581427,None
# 489,2017-02-03 11:00:00,spring,No,Yes,Clear or partly cloudy,,6.82,43,30.0026,4.1588830833596715,None
# 490,2017-02-03 12:00:00,spring,No,Yes,Clear or partly cloudy,8.2,9.09,40,23.9994,4.23410650459726,None
# 491,2017-02-03 13:00:00,spring,No,Yes,Clear or partly cloudy,8.2,8.335,40,27.9993,3.9318256327243257,None
# 492,2017-02-03 14:00:00,spring,No,Yes,Clear or partly cloudy,9.02,9.85,37,26.0027,3.8501476017100584,None
# ...
# 8553,2018-07-17 17:00:00,fall,No,Yes,Clear or partly cloudy,37.72,40.91,29,0.0,6.646390514847729,None
# 8554,2018-07-17 18:00:00,fall,No,Yes,Clear or partly cloudy,36.9,40.15,33,12.998,6.648984550024776,None
# 8555,2018-07-17 19:00:00,fall,No,Yes,Clear or partly cloudy,36.08,39.395,35,16.9979,6.304448802421981,None
# 8556,2018-07-17 20:00:00,fall,No,Yes,Clear or partly cloudy,35.26,37.88,34,11.0014,6.056784013228625,None
# 8557,2018-07-17 21:00:00,fall,No,Yes,Clear or partly cloudy,33.62,38.635,52,8.9981,5.808142489980444,None
# 8558,2018-07-17 22:00:00,fall,No,Yes,Clear or partly cloudy,,37.88,55,15.0013,5.497168225293202,None
# 8559,2018-07-17 23:00:00,fall,No,Yes,Clear or partly cloudy,31.98,37.12,59,12.998,5.081404364984463,None
# 8560,2018-07-18 00:00:00,fall,No,Yes,Clear or partly cloudy,31.16,36.365,66,11.0014,3.970291913552122,None
# 8561,2018-07-18 01:00:00,fall,No,Yes,Clear or partly cloudy,31.16,36.365,66,7.0015,2.772588722239781,None
# 8562,2018-07-18 02:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,8.9981,2.0794415416798357,None
# 8563,2018-07-18 03:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,8.9981,1.3862943611198906,None
# 8564,2018-07-18 04:00:00,fall,No,Yes,Clear or partly cloudy,,34.09,70,8.9981,1.791759469228055,None
# 8565,2018-07-18 05:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,11.0014,3.828641396489095,None
# 8566,2018-07-18 06:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,,5.087596335232384,None
# 8567,2018-07-18 07:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,11.0014,6.20455776256869,None
# 8568,2018-07-18 08:00:00,fall,No,Yes,Clear or partly cloudy,31.98,37.12,62,7.0015,6.520621127558696,None
# 8569,2018-07-18 09:00:00,fall,No,Yes,Clear or partly cloudy,33.62,39.395,56,0.0,5.6937321388027,None
# 8570,2018-07-18 10:00:00,fall,No,Yes,Clear or partly cloudy,36.9,42.425,42,12.998,4.927253685157205,None
# 8571,2018-07-18 11:00:00,fall,No,Yes,Clear or partly cloudy,36.9,42.425,42,0.0,5.209486152841421,None
# 8572,2018-07-18 12:00:00,fall,No,Yes,Clear or partly cloudy,37.72,43.18,37,8.9981,5.308267697401205,None
# 8573,2018-07-18 13:00:00,fall,No,Yes,Clear or partly cloudy,38.54,42.425,33,0.0,5.313205979041787,None
# 8574,2018-07-18 14:00:00,fall,No,Yes,Clear or partly cloudy,38.54,43.94,38,22.0028,5.135798437050262,None
# 8575,2018-07-18 15:00:00,fall,No,Yes,Light snow or rain,37.72,42.425,35,23.9994,5.267858159063328,None
# 8576,2018-07-18 16:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,16.9979,5.41164605185504,None
# 8577,2018-07-18 17:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,70,16.9979,5.91350300563827,None
# 8578,2018-07-18 18:00:00,fall,No,Yes,Mist,31.16,35.605,62,8.9981,6.466144724237619,None
# 8579,2018-07-18 19:00:00,fall,No,Yes,Mist,31.16,35.605,62,7.0015,6.246106765481563,None
# 8580,2018-07-18 20:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.09,62,6.0032,5.902633333401366,None
# 8581,2018-07-18 21:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,62,0.0,5.765191102784844,None
# 8582,2018-07-18 22:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,58,6.0032,5.662960480135946,None
# 8583,2018-07-18 23:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,58,6.0032,4.875197323201151,None
# 8584,2018-07-19 00:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,6.0032,4.189654742026425,None
# 8585,2018-07-19 01:00:00,fall,No,Yes,Clear or partly cloudy,,34.85,66,6.0032,3.218875824868201,None
# 8586,2018-07-19 02:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,12.998,1.9459101490553132,None
# 8587,2018-07-19 03:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,7.0015,1.6094379124341005,None
# 8588,2018-07-19 04:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,7.0015,2.0794415416798357,None
# 8589,2018-07-19 05:00:00,fall,No,Yes,Mist,29.52,34.09,70,7.0015,3.688879454113936,None
# 8590,2018-07-19 06:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,66,8.9981,5.0238805208462765,None
# 8591,2018-07-19 07:00:00,fall,No,Yes,Clear or partly cloudy,,34.09,58,19.0012,6.159095388491933,None
# 8592,2018-07-19 08:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,58,16.9979,6.48768401848461,None
# 8593,2018-07-19 09:00:00,fall,No,Yes,Mist,31.16,35.605,58,19.0012,5.762051382780177,None
# 8594,2018-07-19 10:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,58,12.998,5.288267030694535,None
# 8595,2018-07-19 11:00:00,fall,No,Yes,Clear or partly cloudy,,37.88,55,7.0015,5.375278407684165,None
# 8596,2018-07-19 12:00:00,fall,No,Yes,Clear or partly cloudy,34.44,39.395,49,19.0012,5.6131281063880705,None
# 8597,2018-07-19 13:00:00,fall,No,Yes,Clear or partly cloudy,34.44,38.635,47,8.9981,5.537334267018537,None
# 8598,2018-07-19 14:00:00,fall,No,Yes,Clear or partly cloudy,,39.395,44,6.0032,5.2832037287379885,None
# 8599,2018-07-19 15:00:00,fall,No,Yes,Clear or partly cloudy,34.44,38.635,47,6.0032,5.676753802268282,None
# 8600,2018-07-19 16:00:00,fall,No,Yes,Clear or partly cloudy,34.44,38.635,47,6.0032,5.8805329864007,None
# 8601,2018-07-19 17:00:00,fall,No,Yes,Clear or partly cloudy,35.26,39.395,41,0.0,6.647688373563329,None
# 8602,2018-07-19 18:00:00,fall,No,Yes,Clear or partly cloudy,,39.395,41,12.998,6.655440350367647,None
# 8603,2018-07-19 19:00:00,fall,No,Yes,Clear or partly cloudy,,37.88,44,16.9979,6.278521424165844,None
# 8604,2018-07-19 20:00:00,fall,No,Yes,Clear or partly cloudy,33.62,38.635,49,11.0014,6.22455842927536,None
# 8605,2018-07-19 21:00:00,fall,No,Yes,Light snow or rain,27.06,29.545,89,16.9979,5.805134968916488,None
# 8606,2018-07-19 22:00:00,fall,No,Yes,Light snow or rain,27.06,29.545,89,16.9979,4.219507705176107,None
# 8607,2018-07-19 23:00:00,fall,No,Yes,Light snow or rain,27.06,29.545,89,15.0013,4.174387269895637,None
# 8608,2018-08-01 00:00:00,fall,No,Yes,Clear or partly cloudy,27.88,31.82,79,11.0014,3.8501476017100584,None
# 8609,2018-08-01 01:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,6.0032,3.49650756146648,None
# 8610,2018-08-01 02:00:00,fall,No,Yes,Clear or partly cloudy,26.24,28.79,83,7.0015,2.5649493574615367,None
# 8611,2018-08-01 03:00:00,fall,No,Yes,Clear or partly cloudy,26.24,28.79,83,7.0015,1.9459101490553132,None
# 8612,2018-08-01 04:00:00,fall,No,Yes,Mist,26.24,29.545,78,8.9981,1.3862943611198906,None
# 8613,2018-08-01 05:00:00,fall,No,Yes,Mist,26.24,29.545,78,8.9981,3.8918202981106265,None
# 8614,2018-08-01 06:00:00,fall,No,Yes,Clear or partly cloudy,26.24,29.545,78,8.9981,5.220355825078324,None
# 8615,2018-08-01 07:00:00,fall,No,Yes,Mist,26.24,28.79,83,8.9981,6.18826412308259,None
# 8616,2018-08-01 08:00:00,fall,No,Yes,Mist,27.06,30.305,78,12.998,6.523562306149512,None
# 8617,2018-08-01 09:00:00,fall,No,Yes,Mist,,31.82,74,6.0032,5.857933154483459,None
# 8618,2018-08-01 10:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,66,6.0032,5.4638318050256105,None
# 8619,2018-08-01 11:00:00,fall,No,Yes,Clear or partly cloudy,31.16,35.605,58,6.0032,5.455321115357702,None
# 8620,2018-08-01 12:00:00,fall,No,Yes,Clear or partly cloudy,32.8,37.12,49,7.0015,5.648974238161206,None
# 8621,2018-08-01 13:00:00,fall,No,Yes,Clear or partly cloudy,,37.12,52,11.0014,5.634789603169249,None
# 8622,2018-08-01 14:00:00,fall,No,Yes,Clear or partly cloudy,33.62,37.88,46,11.0014,5.572154032177765,None
# 8623,2018-08-01 15:00:00,fall,No,Yes,Clear or partly cloudy,33.62,37.88,46,11.0014,5.68697535633982,None
# 8624,2018-08-01 16:00:00,fall,No,Yes,Clear or partly cloudy,32.8,37.88,55,19.0012,6.171700597410915,None
# 8625,2018-08-01 17:00:00,fall,No,Yes,Clear or partly cloudy,32.8,37.12,49,11.0014,6.729824070489475,None
# 8626,2018-08-01 18:00:00,fall,No,Yes,Light snow or rain,31.16,35.605,62,15.0013,6.792344427470809,None
# 8627,2018-08-01 19:00:00,fall,No,Yes,Clear or partly cloudy,,34.85,66,16.9979,6.480044561926653,None
# 8628,2018-08-01 20:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,66,11.0014,6.240275845170769,None
# 8629,2018-08-01 21:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,8.9981,5.768320995793772,None
# 8630,2018-08-01 22:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,7.0015,5.662960480135946,None
# 8631,2018-08-01 23:00:00,fall,No,Yes,Clear or partly cloudy,28.7,33.335,74,0.0,5.0238805208462765,None
# 8632,2018-08-02 00:00:00,fall,No,Yes,Clear or partly cloudy,,33.335,74,0.0,4.143134726391533,None
# 8633,2018-08-02 01:00:00,fall,No,Yes,Clear or partly cloudy,27.88,31.82,79,7.0015,3.737669618283368,None
# 8634,2018-08-02 02:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,,6.0032,2.3978952727983707,None
# 8635,2018-08-02 03:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,0.0,1.791759469228055,None
# 8636,2018-08-02 04:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,0.0,2.1972245773362196,None
# 8637,2018-08-02 05:00:00,fall,No,Yes,Clear or partly cloudy,27.06,29.545,89,8.9981,3.713572066704308,None
# 8638,2018-08-02 06:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,0.0,5.209486152841421,None
# 8639,2018-08-02 07:00:00,fall,No,Yes,Clear or partly cloudy,28.7,33.335,79,0.0,6.159095388491933,None
# 8640,2018-08-02 08:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.85,74,7.0015,6.6052979209482015,None
# 8641,2018-08-02 09:00:00,fall,No,Yes,Clear or partly cloudy,31.16,36.365,66,7.0015,5.8377304471659395,None
# 8642,2018-08-02 10:00:00,fall,No,Yes,Clear or partly cloudy,32.8,37.88,55,0.0,5.198497031265826,None
# 8643,2018-08-02 11:00:00,fall,No,Yes,Clear or partly cloudy,33.62,38.635,52,7.0015,5.420534999272286,None
# 8644,2018-08-02 12:00:00,fall,No,Yes,Clear or partly cloudy,34.44,37.88,44,8.9981,5.655991810819852,None
# 8645,2018-08-02 13:00:00,fall,No,Yes,Clear or partly cloudy,35.26,39.395,44,15.0013,5.736572297479192,None
# 8646,2018-08-02 14:00:00,fall,No,Yes,Clear or partly cloudy,,39.395,41,8.9981,5.41610040220442,None
# 8647,2018-08-02 15:00:00,fall,No,Yes,Clear or partly cloudy,31.98,37.12,62,31.0009,5.598421958998375,None
# 8648,2018-08-02 16:00:00,fall,No,Yes,Clear or partly cloudy,33.62,37.88,46,12.998,6.0063531596017325,None
# 8649,2018-08-02 17:00:00,fall,No,Yes,Clear or partly cloudy,33.62,38.635,52,16.9979,6.762729506931879,None
# 8650,2018-08-02 18:00:00,fall,No,Yes,Clear or partly cloudy,32.8,38.635,59,15.0013,6.642486801367256,None
# 8651,2018-08-02 19:00:00,fall,No,Yes,Clear or partly cloudy,32.8,39.395,,11.0014,6.408528791059498,None
# 8652,2018-08-02 20:00:00,fall,No,Yes,Clear or partly cloudy,,37.88,66,0.0,6.056784013228625,None
# 8653,2018-08-02 21:00:00,fall,No,Yes,Clear or partly cloudy,31.16,36.365,66,15.0013,5.834810737062605,None
# 8654,2018-08-02 22:00:00,fall,No,Yes,Clear or partly cloudy,30.34,34.85,70,12.998,5.568344503761097,None
# 8655,2018-08-02 23:00:00,fall,No,Yes,Clear or partly cloudy,,34.09,70,16.9979,5.176149732573829,None
# 8656,2018-08-03 00:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,12.998,4.2626798770413155,None
# 8657,2018-08-03 01:00:00,fall,No,Yes,Clear or partly cloudy,28.7,33.335,74,12.998,3.7612001156935624,None
# 8658,2018-08-03 02:00:00,fall,No,Yes,Clear or partly cloudy,27.88,31.82,79,15.0013,2.6390573296152584,None
# 8659,2018-08-03 03:00:00,fall,No,Yes,Clear or partly cloudy,27.88,31.82,79,15.0013,1.791759469228055,None
# 8660,2018-08-03 04:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,16.9979,2.4849066497880004,None
# 8661,2018-08-03 05:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,,11.0014,3.610917912644224,None
# 8662,2018-08-03 06:00:00,fall,No,Yes,Clear or partly cloudy,27.06,30.305,83,15.0013,5.093750200806762,None
# 8663,2018-08-03 07:00:00,fall,No,Yes,Clear or partly cloudy,28.7,33.335,74,7.0015,6.042632833682381,None
# 8664,2018-08-03 08:00:00,fall,No,Yes,Clear or partly cloudy,29.52,34.09,70,8.9981,6.504288173536645,None
# 8665,2018-08-03 09:00:00,fall,No,Yes,Mist,30.34,34.85,66,7.0015,5.981414211254481,None
# 8666,2018-08-03 10:00:00,fall,No,Yes,Mist,32.8,37.12,52,12.998,5.517452896464707,None
# 8667,2018-08-03 11:00:00,fall,No,Yes,Mist,34.44,39.395,49,19.0012,5.572154032177765,None
# 8668,2018-08-03 12:00:00,fall,No,Yes,Mist,,40.91,50,19.9995,5.823045895483019,None
# 8669,2018-08-03 13:00:00,fall,No,Yes,Mist,35.26,40.15,47,19.0012,5.84354441703136,None
# 8670,2018-08-03 14:00:00,fall,No,Yes,Mist,35.26,39.395,44,16.9979,5.802118375377063,None
# 8671,2018-08-03 15:00:00,fall,No,Yes,Clear or partly cloudy,36.08,40.91,42,,5.940171252720432,None
# 8672,2018-08-03 16:00:00,fall,No,Yes,Mist,35.26,39.395,41,15.0013,6.198478716492308,None
# 8673,2018-08-03 17:00:00,fall,No,Yes,Mist,34.44,40.15,53,19.0012,6.608000625296087,None
# 8674,2018-08-03 18:00:00,fall,No,Yes,Mist,33.62,40.15,59,16.9979,6.508769136971682,None
# 8675,2018-08-03 19:00:00,fall,No,Yes,Mist,32.8,39.395,63,,6.150602768446279,None
# 8676,2018-08-03 20:00:00,fall,No,Yes,Mist,31.98,37.88,66,15.0013,5.963579343618446,None
# 8677,2018-08-03 21:00:00,fall,No,Yes,Mist,,36.365,66,12.998,5.627621113690637,None
# 8678,2018-08-03 22:00:00,fall,No,Yes,Clear or partly cloudy,31.16,36.365,70,16.9979,5.308267697401205,None
# 8679,2018-08-03 23:00:00,fall,No,Yes,Clear or partly cloudy,30.34,35.605,79,8.9981,5.278114659230517,None
# 8680,2018-08-04 00:00:00,fall,No,No,Clear or partly cloudy,30.34,35.605,79,11.0014,5.081404364984463,None
# 8681,2018-08-04 01:00:00,fall,No,No,Clear or partly cloudy,29.52,35.605,84,12.998,4.804021044733257,None
# 8682,2018-08-04 02:00:00,fall,No,No,Clear or partly cloudy,29.52,35.605,84,8.9981,4.430816798843313,None
# 8683,2018-08-04 03:00:00,fall,No,No,Clear or partly cloudy,29.52,35.605,84,8.9981,3.4011973816621555,None
# 8684,2018-08-04 04:00:00,fall,No,No,Clear or partly cloudy,29.52,34.85,79,12.998,2.5649493574615367,None
# 8685,2018-08-04 05:00:00,fall,No,No,Clear or partly cloudy,28.7,33.335,84,15.0013,2.833213344056216,None
# 8686,2018-08-04 06:00:00,fall,No,No,Clear or partly cloudy,28.7,33.335,84,15.0013,3.8918202981106265,None
# 8687,2018-08-04 07:00:00,fall,No,No,Clear or partly cloudy,29.52,34.85,77,11.0014,4.204692619390966,None
# 8688,2018-08-04 08:00:00,fall,No,No,Clear or partly cloudy,,36.365,72,12.998,5.198497031265826,None
# 8689,2018-08-04 09:00:00,fall,No,No,Clear or partly cloudy,,37.88,65,15.0013,5.627621113690637,None
# 8690,2018-08-04 10:00:00,fall,No,No,Clear or partly cloudy,33.62,38.635,57,12.998,5.981414211254481,None
# 8691,2018-08-04 11:00:00,fall,No,No,Clear or partly cloudy,35.26,40.15,47,16.9979,6.152732694704104,None
# 8692,2018-08-04 12:00:00,fall,No,No,Clear or partly cloudy,35.26,39.395,40,23.9994,6.304448802421981,None
# 8693,2018-08-04 13:00:00,fall,No,No,Clear or partly cloudy,36.08,40.91,42,19.9995,6.267200548541362,None
# 8694,2018-08-04 14:00:00,fall,No,No,Clear or partly cloudy,36.08,40.15,40,26.0027,6.156978985585555,None
# 8695,2018-08-04 15:00:00,fall,No,No,Clear or partly cloudy,36.08,40.91,42,27.9993,6.192362489474872,None
# 8696,2018-08-04 16:00:00,fall,No,No,Clear or partly cloudy,,40.91,39,19.9995,6.1092475827643655,None
# 8697,2018-08-04 17:00:00,fall,No,No,Clear or partly cloudy,36.08,39.395,37,19.9995,6.198478716492308,None
# 8698,2018-08-04 18:00:00,fall,No,No,Clear or partly cloudy,35.26,39.395,41,22.0028,6.194405391104672,None
# 8699,2018-08-04 19:00:00,fall,No,No,Clear or partly cloudy,33.62,38.635,52,23.9994,5.983936280687191,None
# 8700,2018-08-04 20:00:00,fall,No,No,Clear or partly cloudy,33.62,38.635,52,19.9995,5.7430031878094825,None
# 8701,2018-08-04 21:00:00,fall,No,No,Clear or partly cloudy,32.8,38.635,59,16.9979,5.666426688112432,None
# 8702,2018-08-04 22:00:00,fall,No,No,Clear or partly cloudy,,36.365,66,19.0012,5.594711379601839,None
# 8703,2018-08-04 23:00:00,fall,No,No,Clear or partly cloudy,31.16,36.365,66,19.9995,5.402677381872279,None
# 8704,2018-08-05 00:00:00,fall,No,No,Clear or partly cloudy,30.34,34.85,70,19.0012,5.030437921392435,None
# 8705,2018-08-05 01:00:00,fall,No,No,Clear or partly cloudy,30.34,34.85,70,16.9979,4.465908118654584,None
# 8706,2018-08-05 02:00:00,fall,No,No,Clear or partly cloudy,30.34,34.85,70,19.9995,4.290459441148391,None
# 8707,2018-08-05 03:00:00,fall,No,No,Clear or partly cloudy,29.52,34.85,74,16.9979,3.713572066704308,None
# 8708,2018-08-05 04:00:00,fall,No,No,Clear or partly cloudy,29.52,34.85,74,16.9979,2.6390573296152584,None

# %%
# Question 3
# Create another table named “temperature” by selecting the temp, temp_feel, and temp_category columns. 
#Then drop the temp and temp_feel columns from the CarSharing table.

import sqlite3

# Function to print table data
def print_table_data(table_name, num_rows=5):  # Default to print 5 rows
    conn = sqlite3.connect('carsharing.db')
    cursor = conn.cursor()

    cursor.execute(f"SELECT * FROM {table_name}")
    rows = cursor.fetchall()

    # Print the table name
    print(f"{table_name} Table:")

    # Print the header row
    header = [description[0] for description in cursor.description]
    print(','.join(header))

    # Print the specified number of rows skipping the header row
    for row in rows[1:num_rows + 1]:
        print(','.join(str(col) for col in row))

    conn.close()

# Create an SQLite database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Create the temperature table and insert data
cursor.execute('''CREATE TABLE IF NOT EXISTS temperature (
                    temp REAL,
                    temp_feel REAL,
                    temp_category TEXT
                )''')

cursor.execute('''INSERT INTO temperature (temp, temp_feel, temp_category)
                  SELECT temp, temp_feel, temp_category
                  FROM CarSharing''')

# Drop the temp and temp_feel columns from the CarSharing table
cursor.execute('''ALTER TABLE CarSharing 
                  DROP COLUMN temp''')

cursor.execute('''ALTER TABLE CarSharing 
                  DROP COLUMN temp_feel''')

# Commit the changes
conn.commit()

# Print the new Temperature table with only 5 rows, excluding the header row
print_table_data('temperature', 5)

# Close the connection
conn.close()
# Out:
# temperature Table:
# temp,temp_feel,temp_category
# 9.84,14.395,Mild
# 9.02,13.635,Mild
# 9.02,13.635,Mild
# 9.84,14.395,Mild
# 9.84,14.395,Mild

# %%
#Question 4
#Find the distinct values of the weather column and assign a number to each value. 
#Add another column named “weather_code” to the table containing each row’s assigned weather code.

import sqlite3

# Function to print table data
def print_table_data(table_name, num_rows=5):  
    conn = sqlite3.connect('carsharing.db')
    cursor = conn.cursor()

    # Print the table name
    print(f"Table Name: {table_name}")

    # Fetch and print the specified number of rows, excluding the header row
    cursor.execute(f"SELECT * FROM {table_name}")
    rows = cursor.fetchall()
    header_printed = False
    for i, row in enumerate(rows[1:6], start=1):
        if i == 1 and not header_printed:
            header_printed = True
            print(','.join(str(col) for col in row))
        else:
            print(','.join(str(col) for col in row))

    conn.close()

# Connect to the database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Fetch distinct values of the weather column
cursor.execute("SELECT DISTINCT weather FROM CarSharing")
distinct_weather = cursor.fetchall()

# Assign a unique number to each weather value
weather_codes = {weather[0]: index for index, weather in enumerate(distinct_weather, start=1)}

# Add the weather_code column to the CarSharing table
cursor.execute("ALTER TABLE CarSharing ADD COLUMN weather_code INTEGER")

# Update the weather_code column with assigned codes
for weather, code in weather_codes.items():
    cursor.execute("UPDATE CarSharing SET weather_code = ? WHERE weather = ?", (code, weather))

# Commit the changes
conn.commit()

# Print the modified CarSharing table with weather codes and the first few rows
print_table_data('CarSharing', num_rows=5)

# Print the generated weather codes
print("\nWeather Codes Generated:")
for weather, code in weather_codes.items():
    print(f"{weather}: {code}")

# Close the connection
conn.close()
# Out:
# Table Name: CarSharing
# 1,2017-01-01 00:00:00,spring,No,No,Clear or partly cloudy,81,0.0,2.772588722239781,Mild,2
# 2,2017-01-01 01:00:00,spring,No,No,Clear or partly cloudy,80,0.0,3.688879454113936,Mild,2
# 3,2017-01-01 02:00:00,spring,No,No,Clear or partly cloudy,80,0.0,3.4657359027997265,Mild,2
# 4,2017-01-01 03:00:00,spring,No,No,Clear or partly cloudy,75,0.0,2.5649493574615367,Mild,2
# 5,2017-01-01 04:00:00,spring,No,No,Clear or partly cloudy,75,0.0,0.0,Mild,2
#
# Weather Codes Generated:
# weather: 1
# Clear or partly cloudy: 2
# Mist: 3
# Light snow or rain: 4
# heavy rain/ice pellets/snow + fog: 5

# %%
#Question 5
#Create a table called “weather” and copy the columns “weather” and “weather_code” to this table. 
#Then drop the weather column from the CarSharing table.

import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Create the "weather" table
cursor.execute('''CREATE TABLE IF NOT EXISTS weather (
                    weather TEXT,
                    weather_code INTEGER
                )''')

# Copy the "weather" and "weather_code" columns to the "weather" table
cursor.execute('''INSERT INTO weather (weather, weather_code)
                  SELECT weather, weather_code
                  FROM CarSharing''')

# Drop the "weather" column from the "CarSharing" table
cursor.execute('''ALTER TABLE CarSharing
                  DROP COLUMN weather''')

# Commit the changes to the database
conn.commit()

# Print the table name
print("Table Name: weather")
print()

# Print the header row
header_row = ["weather", "weather_code"]
print("\t".join(header_row))

# Print the first 5 rows from the "weather" table
cursor.execute('''SELECT *
                  FROM weather
                  WHERE ROWID <= 5''')
rows = cursor.fetchall()
for row in rows:
    # Convert the values to strings before joining
    row_values = [str(value) for value in row]
    print("\t".join(row_values))

# Close the database connection
conn.close()
# Out:
# Table Name: weather
#
# weather	weather_code
# weather	1
# Clear or partly cloudy	2
# Clear or partly cloudy	2
# Clear or partly cloudy	2
# Clear or partly cloudy	2

# %%
# QUESTION 6
#Create a table called time with four columns containing each row’s timestamp, hour, weekday name,and 
#month name (Hint: you can use the strftime() function for this purpose).

import sqlite3

# Create an SQLite database connection
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Create the "time" table
cursor.execute('''CREATE TABLE IF NOT EXISTS time (
                    timestamp TEXT,
                    hour TEXT,
                    weekday_name TEXT,
                    month_name TEXT
                )''')

# Extract hour, weekday name, and month name from timestamp and insert into "time" table
cursor.execute('''INSERT INTO time (timestamp, hour, weekday_name, month_name)
                  SELECT timestamp,
                         strftime('%H:%M:%S', timestamp) AS hour,
                         strftime('%A', timestamp) AS weekday_name,
                         strftime('%B', timestamp) AS month_name
                  FROM CarSharing''')

# Commit the changes to the database
conn.commit()

# Fetch and print the header row
cursor.execute('''PRAGMA table_info(time)''')
columns = cursor.fetchall()
header = [col[1] for col in columns]
print(" | ".join(f"{col: <15}" for col in header))  # Ensuring fixed width for alignment

# Fetch and print the first five rows, starting from index 0
cursor.execute('''SELECT * FROM time LIMIT 6''')  # Limit 6 to include the header row
rows = cursor.fetchall()
header_printed = False
for row in rows:
    if not header_printed:
        header_printed = True
        continue  # Skip printing the second row
    print(" | ".join(f"{str(col): <15}" for col in row))

# Close the connection
conn.close()
# Out:
# timestamp       | hour            | weekday_name    | month_name
# 2017-01-01 00:00:00 | 00:00:00        | Sunday          | January
# 2017-01-01 01:00:00 | 01:00:00        | Sunday          | January
# 2017-01-01 02:00:00 | 02:00:00        | Sunday          | January
# 2017-01-01 03:00:00 | 03:00:00        | Sunday          | January
# 2017-01-01 04:00:00 | 04:00:00        | Sunday          | January

# %%
# QUESTION 7a
#Assume it’s the first day you have started working at this company and your boss Linda 
#sends you an email as follows: “Hello, welcome to the team. I hope you enjoy working at this company. 
#Could you please give me a report containing the following information:
# 7a Please tell me which date and time we had the highest demand rate in 2017

import sqlite3

# Connect to the database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Query to find the date, time, and demand rate with the highest demand rate in 2017
cursor.execute('''SELECT timestamp, demand
                  FROM CarSharing
                  WHERE demand = (SELECT MAX(demand) FROM CarSharing WHERE timestamp LIKE '2017-%')''')
result = cursor.fetchone()

# Check if result exists
if result:
    highest_demand_timestamp = result[0]
    highest_demand_demand = result[1]
    print("Date       Time       Demand")
    print(f"{highest_demand_timestamp[:10]}  {highest_demand_timestamp[11:19]}  {highest_demand_demand}")
else:
    print("No data found for the highest demand rate in 2017.")

# Close the connection
conn.close()
# Out:
# Date       Time       Demand
# 2017-06-15  17:00:00  6.45833828334479

# %%
# QUESTION 7b
#Give me a table containing the name of the weekday, month, and season in which we had the 
#highest and lowest average demand rates throughout 2017. 
#Please include the calculated average demand values as well.


import sqlite3

# Connect to the database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Query to calculate average demand rates for each weekday, month, and season in 2017
cursor.execute('''SELECT 
                      CASE strftime('%w', timestamp)
                          WHEN '0' THEN 'Sunday'
                          WHEN '1' THEN 'Monday'
                          WHEN '2' THEN 'Tuesday'
                          WHEN '3' THEN 'Wednesday'
                          WHEN '4' THEN 'Thursday'
                          WHEN '5' THEN 'Friday'
                          ELSE 'Saturday'
                      END AS weekday,
                      CASE strftime('%m', timestamp)
                          WHEN '01' THEN 'January'
                          WHEN '02' THEN 'February'
                          WHEN '03' THEN 'March'
                          WHEN '04' THEN 'April'
                          WHEN '05' THEN 'May'
                          WHEN '06' THEN 'June'
                          WHEN '07' THEN 'July'
                          WHEN '08' THEN 'August'
                          WHEN '09' THEN 'September'
                          WHEN '10' THEN 'October'
                          WHEN '11' THEN 'November'
                          ELSE 'December'
                      END AS month,
                      CASE
                          WHEN strftime('%m', timestamp) IN ('01', '02', '12') THEN 'Winter'
                          WHEN strftime('%m', timestamp) IN ('03', '04', '05') THEN 'Spring'
                          WHEN strftime('%m', timestamp) IN ('06', '07', '08') THEN 'Summer'
                          ELSE 'Autumn'
                      END AS season,
                      AVG(demand) AS avg_demand
                  FROM CarSharing
                  WHERE timestamp LIKE '2017-%'
                  GROUP BY weekday, month, season
                  ORDER BY avg_demand DESC''')

# Fetch the row with the highest average demand rate
highest_avg_demand_row = cursor.fetchone()

# Fetch the row with the lowest average demand rate
lowest_avg_demand_row = cursor.fetchone()

# Print the table header
print("Weekday   Month       Season   Max Avg Demand  Min Avg Demand")

# Print the row with the highest average demand rate
print(f"{highest_avg_demand_row[0]:<10} {highest_avg_demand_row[1]:<11} {highest_avg_demand_row[2]:<8} {highest_avg_demand_row[3]:<15} {lowest_avg_demand_row[3]}")

# Close the connection
conn.close()
# Out:
# Weekday   Month       Season   Max Avg Demand  Min Avg Demand
# Sunday     July        Summer   4.997135078747038 4.9366661512307255

# %%
# QUESTION 7c
#For the weekday selected in (b), please give me a table showing the average demand rate 
#we had at different hours of that weekday throughout 2017. 
#Please sort the results in descending order based on the average demand rates.

import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Define the selected weekday_name
selected_weekday_name = "Sunday"

# Execute the SQL query to calculate the average demand rate for each hour of the selected weekday throughout 2017
query = """
    SELECT
        strftime('%H', timestamp) AS hour,
        AVG(demand) AS average_demand
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017' AND
        strftime('%w', timestamp) = (SELECT strftime('%w', '2017-01-01', 'weekday 0'))
    GROUP BY
        hour
    ORDER BY
        average_demand DESC;
"""
cursor.execute(query)

# Fetch and print the results
print("Hour\tAverage Demand")
print("---------------------")
for row in cursor.fetchall():
    hour, average_demand = row
    print(f"{hour}\t{average_demand}")

# Close the connection
conn.close()
# Out:
# Hour	Average Demand
# ---------------------
# 15	5.537925196766501
# 14	5.513702656176965
# 16	5.496274498482708
# 13	5.478758230367251
# 12	5.457459126923962
# 17	5.367634349646671
# 11	5.290915067582866
# 18	5.241211627173081
# 10	5.074545768738012
# 19	5.041802430032878
# 20	4.790666498034493
# 09	4.683176378243488
# 21	4.6042216294700635
# 22	4.47761997279496
# 23	4.3467540044988375
# 08	4.204916044052769
# 00	4.1349741021373445
# 01	3.8698532861655472
# 02	3.6112321135368823
# 07	3.2940243626024213
# 03	2.7702626411657163
# 06	2.453218590596452
# 04	1.6592273354933094
# 05	1.6491762147587958

# %%
# QUESTION 7d
#Please tell me what the weather was like in 2017. Was it mostly cold, mild, or hot? 
#Which weather condition (shown in the weather column) was the most prevalent in 2017? 
#What was the average, highest, and lowest wind speed and humidity for each month in 2017? 
#Please organise this information in two tables for the wind speed and humidity. 
#Please also give me a table showing the average demand rate for each cold, mild, and hot weather 
#in 2017 sorted in descending order based on their average demand rates.

import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Step 1: Overall Weather Analysis for 2017
query_weather_frequency = """
    SELECT
        temp_category,
        COUNT(*) AS frequency
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        temp_category;
"""
cursor.execute(query_weather_frequency)
weather_frequency = cursor.fetchall()

most_prevalent_weather = max(weather_frequency, key=lambda x: x[1])[0]

print("Overall Weather Analysis for 2017:")
print("-----------------------------------")
print("Weather Condition\tFrequency")
print("-----------------\t---------")
for weather, frequency in weather_frequency:
    print(f"{weather}\t\t{frequency}")
print("\nMost Prevalent Weather Condition in 2017:", most_prevalent_weather)

# Step 2: Monthly Weather Statistics for Wind Speed
query_wind_speed_stats = """
    SELECT
        strftime('%Y-%m', timestamp) AS month,
        AVG(windspeed) AS average_wind_speed,
        MAX(windspeed) AS max_wind_speed,
        MIN(windspeed) AS min_wind_speed
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        month;
"""
cursor.execute(query_wind_speed_stats)
wind_speed_stats = cursor.fetchall()

print("\nMonthly Weather Statistics for Wind Speed in 2017:")
print("----------------------------------------------------")
print("Month\t\tAvg Wind Speed\tMax Wind Speed\tMin Wind Speed")
print("----------------------------------------------------")
for month, avg_speed, max_speed, min_speed in wind_speed_stats:
    print(f"{month}\t{avg_speed:.2f}\t\t{max_speed}\t\t{min_speed}")

# Step 3: Monthly Weather Statistics for Humidity
query_humidity_stats = """
    SELECT
        strftime('%Y-%m', timestamp) AS month,
        AVG(humidity) AS average_humidity,
        MAX(humidity) AS max_humidity,
        MIN(humidity) AS min_humidity
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        month;
"""
cursor.execute(query_humidity_stats)
humidity_stats = cursor.fetchall()

print("\nMonthly Weather Statistics for Humidity in 2017:")
print("-------------------------------------------------")
print("Month\t\tAvg Humidity\tMax Humidity\tMin Humidity")
print("-------------------------------------------------")
for month, avg_humidity, max_humidity, min_humidity in humidity_stats:
    print(f"{month}\t{avg_humidity:.2f}\t\t{max_humidity}\t\t{min_humidity}")

# Step 4: Average Demand Rate for Different Weather Conditions
query_weather_demand = """
    SELECT
        temp_category,
        AVG(demand) AS average_demand
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        temp_category
    ORDER BY
        average_demand DESC;
"""
cursor.execute(query_weather_demand)
weather_demand = cursor.fetchall()

print("\nAverage Demand Rate for Different Weather Conditions in 2017:")
print("--------------------------------------------------------------")
print("Weather Condition\tAverage Demand Rate")
print("-----------------\t-------------------")
for weather, avg_demand in weather_demand:
    print(f"{weather}\t\t\t{avg_demand:.2f}")

# Close the connection
conn.close()
# Out:
# Overall Weather Analysis for 2017:
# -----------------------------------
# Weather Condition	Frequency
# -----------------	---------
# 		75
# Cold		390
# Hot		2297
# Mild		2660
#
# Most Prevalent Weather Condition in 2017: Mild
#
# Monthly Weather Statistics for Wind Speed in 2017:
# ----------------------------------------------------
# Month		Avg Wind Speed	Max Wind Speed	Min Wind Speed
# ----------------------------------------------------
# 2017-01	13.52				0.0
# 2017-02	15.12				0.0
# 2017-03	15.55				0.0
# 2017-04	15.54				0.0
# 2017-05	12.18				0.0
# 2017-06	11.57				0.0
# 2017-07	11.83				0.0
# 2017-08	12.06				0.0
# 2017-09	11.41				0.0
# 2017-10	10.60				0.0
# 2017-11	11.82				0.0
# 2017-12	10.58				0.0
#
# Monthly Weather Statistics for Humidity in 2017:
# -------------------------------------------------
# Month		Avg Humidity	Max Humidity	Min Humidity
# -------------------------------------------------
# 2017-01	56.05				28
# 2017-02	53.58		100		8
# 2017-03	55.87				0
# 2017-04	66.10				22
# 2017-05	71.21				24
# 2017-06	57.99				20
# 2017-07	59.76				17
# 2017-08	62.04				25
# 2017-09	74.51				42
# 2017-10	71.57		100		29
# 2017-11	64.03				27
# 2017-12	64.89				26
#
# Average Demand Rate for Different Weather Conditions in 2017:
# --------------------------------------------------------------
# Weather Condition	Average Demand Rate
# -----------------	-------------------
# Hot			4.80
# 			4.04
# Mild			4.02
# Cold			3.19

# %%
# QUSTION 7e
#Give me another table showing the information requested in (d) for the month 
#we had the highest average demand rate in 2017 so that I can compare it with other months.


import sqlite3
import calendar

# Connect to the SQLite database
conn = sqlite3.connect('carsharing.db')
cursor = conn.cursor()

# Step 1: Retrieve the months and their corresponding average demand rates
query_monthly_demand = """
    SELECT
        strftime('%Y-%m', timestamp) AS month,
        AVG(demand) AS average_demand
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        month;
"""
cursor.execute(query_monthly_demand)
monthly_demand = cursor.fetchall()

# Step 2: Retrieve the weather and demand statistics for each month
query_monthly_weather_stats = """
    SELECT
        strftime('%Y-%m', timestamp) AS month,
        temp_category,
        AVG(demand) AS average_demand
    FROM
        CarSharing
    WHERE
        strftime('%Y', timestamp) = '2017'
    GROUP BY
        month, temp_category;
"""
cursor.execute(query_monthly_weather_stats)
monthly_weather_stats = cursor.fetchall()

# Step 3: Create a dictionary to store the weather and demand statistics for each month
monthly_stats_dict = {month: {'Cold': 0, 'Mild': 0, 'Hot': 0} for month, _ in monthly_demand}

# Step 4: Populate the dictionary with the average demand rates for each weather category
for month, weather, avg_demand in monthly_weather_stats:
    monthly_stats_dict[month][weather] = avg_demand

# Step 5: Find the month with the highest average demand rate
highest_demand_month = max(monthly_demand, key=lambda x: x[1])
month_number = int(highest_demand_month[0][-2:])
month_name = calendar.month_name[month_number]
average_demand = highest_demand_month[1]

# Step 6: Print the month with the highest average demand rate in 2017
print(f"The month with the highest average demand rate in 2017 is {month_name} with a rate of {average_demand:.2f}.")

# Step 7: Print the weather and demand statistics comparison table
print("\nWeather and Demand Statistics Comparison:")
print("---------------------------------------------------------------------------")
print("Month      | Weather Condition | Average Demand Rate")
print("-----------|-------------------|---------------------")
for month, stats in monthly_stats_dict.items():
    month_number = int(month[-2:])
    month_name = calendar.month_name[month_number]
    for weather, avg_demand in stats.items():
        print(f"{month_name:<11}| {weather:<17}| {avg_demand:>20.2f}")

# Close the connection
conn.close()
# Out:
# The month with the highest average demand rate in 2017 is July with a rate of 4.79.
#
# Weather and Demand Statistics Comparison:
# ---------------------------------------------------------------------------
# Month      | Weather Condition | Average Demand Rate
# -----------|-------------------|---------------------
# January    | Cold             |                 3.15
# January    | Mild             |                 3.64
# January    | Hot              |                 0.00
# January    |                  |                 3.41
# February   | Cold             |                 3.40
# February   | Mild             |                 3.72
# February   | Hot              |                 4.98
# February   |                  |                 2.85
# March      | Cold             |                 2.66
# March      | Mild             |                 3.80
# March      | Hot              |                 4.74
# March      |                  |                 3.98
# April      | Cold             |                 0.00
# April      | Mild             |                 3.89
# April      | Hot              |                 4.77
# April      |                  |                 4.24
# May        | Cold             |                 0.00
# May        | Mild             |                 3.96
# May        | Hot              |                 5.27
# May        |                  |                 3.88
# June       | Cold             |                 0.00
# June       | Mild             |                 2.42
# June       | Hot              |                 4.77
# June       |                  |                 5.00
# July       | Cold             |                 0.00
# July       | Mild             |                 0.00
# July       | Hot              |                 4.79
# July       |                  |                 4.81
# August     | Cold             |                 0.00
# August     | Mild             |                 0.00
# August     | Hot              |                 4.65
# August     |                  |                 3.95
# September  | Cold             |                 0.00
# September  | Mild             |                 4.42
# September  | Hot              |                 4.57
# September  |                  |                 4.74
# October    | Cold             |                 0.00
# October    | Mild             |                 4.09
# October    | Hot              |                 5.10
# October    |                  |                 3.76
# November   | Cold             |                 0.00
# November   | Mild             |                 4.42
# November   | Hot              |                 4.86
# November   |                  |                 2.65
# December   | Cold             |                 3.52
# December   | Mild             |                 4.30
# December   | Hot              |                 0.00
# December   |                  |                 4.46
